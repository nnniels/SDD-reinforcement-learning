# %% [markdown]
# <div style="font-size:22pt; line-height:25pt; font-weight:bold; text-align:center;">Class 3: Deep Q Networks</div>

# %% [markdown]
# 1. <a href="#everything">Everything you need to know</a>
# 2. <a href="#reminder">Reminder</a>
# 3. <a href="#envs">Environments</a>
#     1. <a href="#cartpole">Cartpole</a>
#     2. <a href="#swingup">Cartpole swing-up</a>
#     3. <a href="#pong">Pong</a>
# 3. <a href="#value-iteration">Value Iteration as a sequence of Supervized Learning problems</a>
# 4. <a href="#experience-replay">Experience Replay</a>
# 5. <a href="#dqn">A deep Q-network</a>
# 6. <a href="#tricks">Making DQN more efficient</a>
#     1. <a href="#optimizer">Changing the optimizer</a>
#     2. <a href="#nb-grad-steps">Several gradient steps</a>
#     3. <a href="#target-networks">Target network</a>
#     4. <a href="#error-clipping">Error clipping</a>
# 7. <a href="#metrics">Metrics</a>
# 8. <a href="#dqn-image">DQN on image-based tasks</a>
# 9. <a href="#further">Going further</a>
# 10. <a href="#challenge">Challenge</a>
#     1. <a href="#bicycle">Bicycle</a>
#     2. <a href="#sti">Structured Treatment Interruptions</a>
#     3. <a href="#turn">Your turn to play</a>

# %% [markdown]
# In the previous classes we saw that one could replace the model-based value iteration process by an approximate value iteration one. When the approximation is done by performing stochastic approximation, we obtain the $Q$ learning algorithm. We saw it was straightforward to extend this to use experience replay memories and batch stochastic gradient descent. In this class, we combine the stochastic gradient descent approach with replay memories and represent $Q$ as a neural network. This yields the Deep Q-Networks algorithm.
#
# There are few new concepts in this class compared to previous ones. Mainly, what we do is bring neural networks into the framework we have previously built. Therefore, this class is aimed at more practice. For this purpose, we start by introducing a set of [environments](#sec1) to illustrate further developments. Then we will start from Value Iteration and repeat the thought process of the previous classes, introduce [stochastic gradient descent](#sec2), [experience replay](#sec3) and reach the [DQN algorithm](#sec4). The end of the class is an [open challenge](#challenge) on several difficult benchmarks.
#
# <div class="alert alert-warning">
#
# **Prerequisites:**
# - Stochastic Approximation for Approximate Value Iteration
# - Deep Learning
# <div>

# %% [markdown]
# Let's start with this quote:
#
# > The idea that we learn by interacting with our environment is probably the first to occur to us when we think about the nature of learning. When an infant plays, waves its arms, or looks about, it has no explicit teacher, but it does have a direct sensorimotor connection to its environment. Exercising this connection produces a wealth of information about cause and effect, about the consequences of actions, and about what to do in order to achieve goals. Throughout our lives, such interactions are undoubtedly a major source of knowledge about our environment and ourselves. Whether we are learning to drive a car or to hold a conversation, we are acutely aware of how our environment responds to what we do, and we seek to influence what happens through our behavior. Learning from interaction is a foundational idea underlying nearly all theories of learning and intelligence. (Richard S. Sutton)

# %% [markdown]
# # <div id="everything"></div>Everything you need to know
#
# Everything you should remember after this session.<br>
# <br>

# %% [markdown]
# <span style="color:#3566B9">
# C'est VRAIMENT tout ce qu'il faut retenir

# %% [markdown]
# <div class="alert alert-success">
#
# - Deep Q-Networks is an approximate value iteration algorithm that uses experience replay and stochastic gradient descent to learn $Q^*$ as a neural network. The DQN itself is the neural network.
# - DQN pseudo-code
# ```
#          state = init()
#          loop:
#             action = greedy_action(DQN) or random_action()
#             new_state, reward = step(state, action)
#             replay_memory.add(state, action, reward, new_state)
#             minibatch = replay_memory.sample(minibatch_size)
#             X_train = Y_train = []
#             for (s, a, r, s') in minibatch:
#                 Q  = DQN.predict(s)
#                 Q' = DQN.predict(s')
#                 if non-terminal(s'):
#                     update = r + gamma * max(Q')
#                 else:
#                     update = r
#                 Q[a] = update
#                 X_train.add(s)
#                 Y_train.add(Q)
#             DQN.train_one_step(X_train, Y_train)
#             state = new_state
# ```
# - The pseudo-code above can be improved by introducing a second network $Q^-$ called *target network*, that is used to compute `update` in the pseudo-code above. Every $C$ steps $Q^-$ is replaced by the learned network.
# - Common improvements to DQN involve using a Huber loss and tuning the optimizer.
# </div>

# %% [markdown]
# <span style="color:#3566B9">
# L'action aléatoire ou greedy est choisie avec la probabilité P définie dans le carnet RL2 (exploration de l'environnement vs choix optimal).

# %% [markdown]
# # <div id="reminder"></div>Reminder
#
# - Value Iteration builds the sequence $Q_{n+1} = T^* Q_n$ that converges to $Q^*$
# - Given a set of samples $\{(s,a,r,s')\}$, one can perform stochastic gradient descent on the loss $L_n(Q) = \|Q - T^* Q_n \|_2$ and thus approximate the sequence of value functions from value iteration.

# %% [markdown]
# <span style="color:#3566B9">
# On a ramené le problème à une minimisation de L. Cette formulation est très ergonomique...

# %% [markdown]
# # <div id="envs"></div>Environments
#
# In this session, we will work with three different environments:
# - CartPole
# - A modified version of CartPole
# - Pong

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## <div id="cartpole"></div>CartPole

# %%
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode='human')

# %% [markdown]
# From the [Gymnasium website](https://gymnasium.farama.org/environments/classic_control/cart_pole/)
#
# > A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart. The pendulum starts upright, and the goal is to prevent it from falling over. A reward of +1 is provided for every timestep that the pole remains upright. The episode ends when the pole is more than 12 degrees from vertical, or the cart moves more than 2.4 units from the center.

# %% [markdown]
# Beware that, as most Gym environments, CartPole has a maximum number of steps before necessarily returning `done=True`.

# %%
cartpole._max_episode_steps
# Out:
# 500

# %% [markdown]
# The cartpole is represented by a state $s = (x, \dot{x}, \theta, \dot{\theta})$ with :
#   - $x$ the position of the cartpole along the x-axis
#   - $\theta$ the angle of the pole

# %%
print(cartpole.action_space)
print(cartpole.observation_space)
print(cartpole.env.metadata)
# Out:
# Discrete(2)
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# {'render_modes': ['human', 'rgb_array'], 'render_fps': 50}

# %%
import time
import numpy as np

_ = cartpole.reset()
cartpole.render()
for i in range(10000):
    _, _, d, _, _ = cartpole.step(np.random.randint(2))
    cartpole.render()
    if d:
        print("Final nb steps:", i)
        break
    time.sleep(cartpole.unwrapped.tau) # not actually real-time, just for readability
time.sleep(3)
cartpole.close()
# Out:
# /home/niels/.sdd_venv/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Final nb steps: 14

# %% [markdown]
# ## <div id="swingup"></div>CartPole Swing-up
#
# The idea here is to keep the same environment, but instead of learning how to stabilize it around the unstable equilibrium point, we'd like to learn to swing it up. Here are the changes:
# - `reset` now puts the pole pointing down. The initial state is $(0,0,\pi,0)$ plus a vector of four uniformly random values in [-0.05,0.05].
# - `step` now returns `done=True` when the cart leaves the $x\in [-2.4,2.4]$ interval or when the pole swings faster than $4\pi$ radians per second.
# - the reward is still +1 for keeping the pole within 12 degrees of the vertical, it is 0 for all other time steps and -10 for swinging too fast or exiting the screen.

# %%
from environments.swingup import CartPoleSwingUp
swingup = CartPoleSwingUp(render_mode="human")

# %%
import numpy as np

x = swingup.reset()
swingup.render()

for i in range(1000):
    _, _, d, _, _ = swingup.step(np.random.randint(2))
    swingup.render()
    if d:
        print("Final nb steps:", i)
        break
    time.sleep(cartpole.unwrapped.tau)
time.sleep(3)
swingup.close()
# Out:
# Final nb steps: 531

# %% [markdown]
# ## <div id="pong"></div>Pong
#
# Let's build an agent that learns to play Pong, one of the [Atari games](https://github.com/openai/gym/blob/master/gym/envs/atari/atari_env.py) in Gym (originally in the [Arcade Learning Environment](https://github.com/mgbellemare/Arcade-Learning-Environment)). You might want to try different games later on (like the popular Breakout game for instance).

# %%
import gymnasium as gym
import ale_py

gym.register_envs(ale_py)
pong = gym.make('ALE/Pong-v5')
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %% [markdown]
# Here is the environment's description.
# > Maximize your score in the Atari 2600 game Pong. In this environment, the observation is an RGB image of the screen, which is an array of shape (210, 160, 3). Each action is repeatedly performed for a duration of k frames, where k is uniformly sampled from $\{2, 3, 4\}$.

# %%
import numpy as np
print(pong.observation_space)
print(pong.observation_space.shape)
print(np.min(pong.observation_space.low))
print(np.max(pong.observation_space.high))
print(pong.action_space)
#help(env.observation_space)
# Out:
# Box(0, 255, (210, 160, 3), uint8)
# (210, 160, 3)
# 0
# 255
# Discrete(6)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
s, _ = pong.reset()
plt.imshow(s)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:** What is the number of possible states? Why is this not an MDP? What would one need to turn this back into an MDP?
# </div>

# %% [markdown]
# <span style="color:#3566B9">
#
# Le nombre d'état : ((210*160)  * 256^3)
#
# C'est l'espace d'état étendu. En vérité, toutes les possibilités ne sont pas avérées (il n'y aura pas apparition d'image de snoopy en 210 par 160 au milieu de la partie.).
#
#
#
# Ce n'est pas un MDP parce qu'on n'a pas la vitesse de la balle : connaissant un état s, on ne peut pas déterminer l'état suivant s'.
#
# Il faut donc définir l'état comme étant __plusieurs images__ pour avoir un problème MDP.
#
# Le fait d'utiliser toute l'image directement dans le NN, au lieu de traiter l'image puis d'envoyer au NN uniquement la vitesse et la position de la balle et la position de la raquette est une démonstration de force : on peut le faire.

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# One frame is a $210\times 160$ RGB image with a 256 color palette, so the set of all possible frames has size $256^{210 \times 160 \times 3} \sim 10^{242579}$. That's a little too many for an efficient enumeration. Of course, most of the possible images will never occur in a Breakout game and the true state space is actually a much smaller subset of the full set of possible images. Nevertheless, unless we provide a large engineering effort in describing the state space with few variables (which would be contradictory of our goal of a "human-level" AI) we will need to automatically discover some structure in the state sampled data.
#
# This is not an MDP because the transition dynamics do not respect Markov's property. The probability of transitioning from $s_t$ to $s_{t+1}$ is *not* independent of previous states. The problem here is that a single frame of the game does not reflect the velocity of the ball.
#
# To recover Markov's property one could simply stack a few frames together in the state space.
# </details>

# %% [markdown]
# There are 18 buttons on the Atari controller. However not all games use all buttons. Our interface to Pong specifies 6 possible actions:
# - 0 NOOP (no operation)
# - 1 FIRE (press fire button, doesn't do anything in Pong)
# - 2 RIGHT (actually moves the paddle up in Pong)
# - 3 LEFT (actually moves the paddle down in Pong)
# - 4 UP (moves the paddle upwards)
# - 5 DOWN (moves the paddle downwards)
#
# The available actions in Pong go up to the 6th action for naming consistency (UP and DOWN), but the four first actions are not really useful.
#
# Also, for an unknown reason, the game does not start until the 20th frame (but always starts automatically, pressing FIRE does not change anything).
#
# The frame rate is 60Hz.
#
# To avoid confusion between the 6 actions allowed by Gym, let's build a wrapper around our environment, with only 2 possible actions ("0" for UP and "1" for DOWN) and a downscaled observation space. Unless you're curious and want to dig in the code, you can simply run the following cells and just use the resulting environment.

# %%
from environments.pongwrapper import PongWrapper

# %%
pong = PongWrapper(
    render_mode="human",
    noop_max=0,
    frame_skip=4,
    terminal_on_life_loss=True,
    grayscale_obs=True,
    scale_obs=True,
)
# Out:
# ALSA lib ../.././../src/v1.2.13-3eeec0cd85.clean/src/pcm/pcm_dmix.c:1000:(snd_pcm_dmix_open) unable to open slave

# %%
# Trying a random agent in Pong
import time
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

pong.reset()
for i in range(60):
    a = np.random.randint(2)
    s, r, _, _, _ = pong.step(a)
    time.sleep(1 / 60)
    
pong.close()
print("shape: ", s.shape, ", min = ", s.min(), ", max = ", s.max(), ", dtype = ", s.dtype, sep='')
plt.imshow(s, cmap='gray');
# Out:
# shape: (84, 84), min = 0.34117648, max = 0.9137255, dtype = float32

# %%
pong = PongWrapper(
    noop_max=0,
    frame_skip=4,
    terminal_on_life_loss=True,
    grayscale_obs=True,
    scale_obs=True,
)

# %% [markdown]
# # <div id="value-iteration"></div>Value Iteration as a sequence of Supervized Learning problems
#
# Recall the Value Iteration update: $Q_{n+1} = T^*Q_n$.
#
# <div class="alert alert-warning">
#
# **Exercise:**
# Suppose $Q_{n+1}$ is a parametric function $Q(s,a;\theta_{n+1})$ with parameters $\theta_{n+1}$. We want to approximate $T^*Q_n$ with $Q(s,a;\theta_{n+1})$. Write the loss function minimized for this regression problem.
# </div>

# %% [markdown]
# <span style="color:#3566B9">
# θ est un paramètre de la fonction, qui correspond aux poids de notre réseau de neurones.

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# Let's start over from the beginning. We want to find:
# $$\pi^*(s) = \arg\max_{\pi} \mathbb{E}_{\left(r_t\right)_{t\in \mathbb{N}}} \left[ \sum_{t=0}^\infty \gamma^t r_t \ \Big| \ s, \pi \right], \ \forall s\in S.$$
#
# We have seen this was equivalent to finding the optimal value function $Q^*$:
# $$Q^*(s,a) = \max_{\pi} \mathbb{E}_{\left(r_t\right)_{t\in \mathbb{N}}} \left[ \sum_{t=0}^\infty \gamma^t r_t \ \Big| \  s,a, \pi \right], \ \forall (s,a) \in S\times A.$$
#
# And we have established that $Q^*$ was the only solution to Bellman's optimality equation:
# $$Q(s,a) = \mathbb{E}_{s' \sim p(\cdot|s,a)} \left[r(s,a,s') + \gamma \max_{a'} Q(s',a')\right].$$
#
# By writing $T^*$ Bellman's optimality operator, we have, by definition:
# $$(T^*Q)(s,a) = \mathbb{E}_{s' \sim p(\cdot|s,a)} \left[r(s,a,s') + \gamma \max_{a'} Q(s',a')\right].$$
#
# And thus, $Q^*$ is the only solution to $Q=T^*Q$.
#
# It appears $T^*$ is a contraction mapping on the $\mathcal{F}(S\times A,\mathbb{R})$ space. Value Iteration exploits this property to build the sequence $Q_{n+1} = T^*Q_n$ which converges to $Q^*$.
#
# Let's now suppose that $Q_n$ is a function approximator, whose parameters are $\theta_n$. We shall write $Q_n(s,a) = Q(s,a;\theta_n)$. Then building $\theta_{n+1}$ knowing $\theta_n$ is the regression problem that minimizes the loss:
# \begin{gather}
# L_n(\theta) = \left\| y_n(s,a) - Q(s,a;\theta) \right\|,\\
# \textrm{with } y_n(s,a) = \mathbb{E}_{s' \sim p(\cdot|s,a)} \left[r(s,a,s') + \gamma \max_{a'} Q(s',a';\theta_{n})\right].
# \end{gather}
#
# If this loss can be optimized and goes to zero, then we have found the true $Q_{n+1}$. If not, then we have found an approximation of it in the norm used to define $L_n$.
#
# </details>

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Use the L2 norm in the loss of the regression problem above, then write the gradient of the loss with respect to the regressor's parameters. Use this to introduce a stochastic gradient descent method to find $\theta_{n+1}$.
# </div>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# Our loss becomes:
# \begin{gather}
# L_n(\theta) = \frac{1}{2} \mathbb{E}_{(s,a) \sim \rho(\cdot)}\left[ \big( y_n(s,a) - Q(s,a;\theta) \big)^2 \right],\\
# \textrm{with } y_n(s,a) = \mathbb{E}_{s' \sim p(\cdot|s,a)} \left[r(s,a,s') + \gamma \max_{a'} Q(s',a';\theta_{n})\right].
# \end{gather}
#
# In the expression above, $\rho$ is a distribution over the state-action space. Often, it is considered to be the behavior distribution, that is the distribution of samples under the current behavior policy, like $\epsilon$-greedy. Note that this choice is debatable.
#
# So the gradient of this loss is:
# \begin{gather}
# \nabla_\theta L_n(\theta) = \mathbb{E}_{(s,a) \sim \rho(\cdot)}\left[ \big( y_n(s,a) - Q(s,a;\theta) \big) \nabla_\theta Q(s,a;\theta) \right]\\
# \textrm{with } y_n(s,a) = \mathbb{E}_{s' \sim p(\cdot|s,a)} \left[r(s,a,s') + \gamma \max_{a'} Q(s',a';\theta_{n})\right].
# \end{gather}
#
# And when we wrap all this together:
# $$\nabla_\theta L_n(\theta) = \mathbb{E}_{(s,a) \sim \rho(\cdot)}\left[ \left( \mathbb{E}_{s' \sim p(\cdot|s,a)} \left[r(s,a,s') + \gamma \max_{a'} Q(s',a';\theta_{n})\right] - Q(s,a;\theta) \right) \nabla_\theta Q(s,a;\theta) \right]$$
#
# $$\nabla_\theta L_n(\theta) = \mathbb{E}_{\substack{(s,a) \sim \rho(\cdot)\\ s' \sim p(\cdot|s,a)}}\left[ \left( r(s,a,s') + \gamma \max_{a'} Q(s',a';\theta_{n}) - Q(s,a;\theta) \right) \nabla_\theta Q(s,a;\theta) \right]$$
#
# We can build a Monte Carlo estimate of this gradient, given a mini-batch of independently and identically drawn samples $\left\{\left(s_i,a_i,r_i,s'_i\right)\right\}_{i\in [1,B]}$, with $(s,a) \sim \rho(\cdot)$ and $s' \sim p(\cdot | s,a)$:
# $$\nabla_\theta L_n(\theta) \approx d_n(\theta) = \sum_{i=1}^B \left[ \left( r_i + \gamma \max_{a'} Q(s_i',a';\theta_{n}) - Q(s_i,a_i;\theta) \right) \nabla_\theta Q(s_i,a_i;\theta) \right].$$
#
# The stochastic gradient descent procedure builds a sequence of parameter values $\theta_k$ such that:
# $$\theta_{k+1} \leftarrow \theta_{k} - \alpha d_n(\theta_{k})$$
#
# By repeating such gradient steps, one progressively minimizes $L_n(\theta)$ and finds $\theta_{n+1}$.
#
# </details>

# %% [markdown]
# <span style="color:#3566B9">
#
# On calcule le gradient par rapport à θ. θn est une constante. La sortie Yn dépend de θn, et pas de θ.
#
# On estime le gradient à l'aide d'un échantillon de B futurs possibles, qui nous donne une pseudo-espérance.

# %% [markdown]
# **Important remark:**
#
# In the update above, if the mini-batch contains a single element, the 1-sample update is precisely that of Q-learning! Then, in Q-learning, the new loss $L_{n+1}$ is defined and the process is repeated. Consequently, there is a new loss function at each time step.
#
# <div class="alert alert-warning">
#
# **Exercise:** can you spot the (subtle but essential) difference with Q-learning?
# </div>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# Recall Q-learning. The update was indeed the same, except that at any time step the mini-batch's single element was not sampled independently from the previous minibatch ! Indeed, $s'$ from the previous time step becomes $s$ for the current time step. So the successive mini-batches' elements are not drawn iid.
#
# That's a key difference that questions the foundation of Q-learning in itself.
# </details>

# %% [markdown]
# # <div id="experience-replay"></div>Experience Replay
#
# To recover the independence assumption between samples, we can introduce the mechanism of [*Experience Replay*](http://www.incompleteideas.net/lin-92.pdf) by storing past samples into a *Replay Memory*. When samples are required for a mini-batch gradient update, they are collected uniformly from the replay memory, thus mimicking an (almost) independent draw according to $\rho(\cdot)$.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Design a class for the replay memory of the cart-pole example(s). Limit the size of this memory (via a FIFO mechanism) to $10^6$ samples (adapt this number to your computer's RAM). Test it by running a random policy for $2\cdot 10^6$ time steps.
# </div>

# %%
# %load solutions/RL5_exercise1.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

# Replay buffer class
import random
from tqdm import trange

"""utils Class for a FIFO list"""
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.data = []
        self.index = 0 # index of the next cell to be filled

    def append(self, s, a, r, s_, d):
        """(s, a, r, s'), d : done"""
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d)
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.data, batch_size)

    def __len__(self):
        return len(self.data)

# %% [markdown]
# <span style="color:#3566B9">
# Les systèmes de listes pour le buffer peuvent être assez critique, parce qu'en fonction de la complexité d'accès et des méthodes d'ajout, tout peut patiner dans la semoule.

# %%
cartpole = gym.make("CartPole-v1")

# Testing insertion in the ReplayBuffer class
replay_buffer_size = int(1e6)
nb_samples = int(2e6)

memory = ReplayBuffer(replay_buffer_size)
state, _ = cartpole.reset()
for _ in trange(nb_samples):
    action = cartpole.action_space.sample()
    next_state, reward, done, _, _ = cartpole.step(action)
    memory.append(state, action, reward, next_state, done)
    if done:
        state, _ = cartpole.reset()
    else:
        state = next_state

print(len(memory))

# Testing sampling in the ReplayBuffer class
nb_batches = int(1e4)
batch_size = 50

for _ in trange(nb_batches):
    batch = memory.sample(batch_size)

print(memory.sample(2))
# Out:
# 100%|██████████| 2000000/2000000 [00:31<00:00, 63843.58it/s]
# 1000000
# 100%|██████████| 10000/10000 [00:00<00:00, 38836.72it/s]
# [(array([-0.00801166,  0.0219783 , -0.05360044, -0.02041619], dtype=float32), np.int64(0), 1.0, array([-0.00757209, -0.17233562, -0.05400876,  0.2548851 ], dtype=float32), False), (array([-0.12078672, -0.8303808 ,  0.09187441,  1.335965  ], dtype=float32), np.int64(1), 1.0, array([-0.13739434, -0.63652873,  0.11859371,  1.0733863 ], dtype=float32), False)]

# %% [markdown]
# <div class="alert alert-warning">
#
# **Know your data structures!**
#
# Taking the time to think about what makes a good replay buffer may save you hours of puzzled head-banging. It is important to know what you expect from your replay buffer to choose the right data structure.
#
# Common mistake: we need a fixed sized memory, that works like a FIFO structure, so let's pick a deque. That sounds fair, deques (in Python) have a fixed maximum size and constant time insertion at the beginning and the end. BUT they also have $O(n)$ access time which means that for large replay buffers, sampling a minibatch may take forever.
#
# Here, what we really need is a fixed-size FIFO, with $O(1)$ insertion at the end and $O(1)$ access.
#
# This should motivate the choices made in the replay buffer class above.
# </div>

# %% [markdown]
# # <div id="dqn"></div>A deep Q-network
#
# The term Deep Q-Network was coined by the (now historical) paper **[Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602)** by Mnih et al. (2013) that put forward the main ideas we develop here. All those were later popularized by DeepMind's paper in Nature **[Human-level control through deep reinforcement learning](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning)** by Mnih et al. (2015).
#
# Let's design a (deep) neural network that will serve as a function approximator for $Q(s,a;\theta)$.
#
# <center><img src="img/dqlas.png" height="15%" width="15%"></img></center>
#
# Note that since we're going to have to compute $\max_a Q(s,a)$ it is preferable to avoid running as many passes through the network as there are actions. Therefore, instead of the network structure above, we will prefer to use the one below.
#
# <center><img src="img/dqls.png" height="30%" width="30%"></img></center>

# %% [markdown]
# <span style="color:#3566B9">
# Le réseau mange l'état S et pond la Q-value pour toutes les actions.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Declare a neural network for our $Q$ function. For the CartPole task, you can use a simple network with 2 hidden layers and 24 neurons on each layer. For the SwingUp task, go up to 50 neurons per layer. For Pong and the other environments... well wait a minute, we'll get to it later.
# </div>

# %%
# %load solutions/RL5_exercise2.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

import torch
import torch.nn as nn
import ale_py
import gymnasium as gym
from environments.swingup import CartPoleSwingUp
import matplotlib.pyplot as plt


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

state_dim = 4 # carpole
n_action = 2 # left or right
nb_neurons = 24

DQN = torch.nn.Sequential(
    # entry
    nn.Linear(state_dim, nb_neurons),
    nn.ReLU(),
    nn.Linear(nb_neurons, nb_neurons),
    nn.ReLU(),
    nn.Linear(nb_neurons, n_action)
).to(device)

# %% [markdown]
# We're almost there. Now you can implement the algorithm that:
# - takes $\epsilon$-greedy actions with respect to $Q$
# - stores samples in the replay buffer
# - at each interaction step with the environment, draws a mini-batch, computes the target values for each $(s,a)$ and takes a gradient step.
# - repeats

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Write this algorithm's pseudo-code, then proceed with your implementation, using the network and replay buffer you defined in the previous cells.
# </div>
#
# You can take inspiration from the algorithm on page 5 of **[Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602)**.

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
#          state = init()
#          loop:
#             action = greedy_action(DQN) or random_action()
#             new_state, reward = step(state, action)
#             replay_memory.add(state, action, reward, new_state)
#             minibatch = replay_memory.sample(minibatch_size)
#             X_train = Y_train = []
#             for (s, a, r, s') in minibatch:
#                 Q  = DQN.predict(s)
#                 Q' = DQN.predict(s')
#                 if non-terminal(s'):
#                     update = r + gamma * max(Q')
#                 else:
#                     update = r
#                 Q[a] = update
#                 X_train.add(s)
#                 Y_train.add(Q)
#             DQN.train_one_step(X_train, Y_train)
#             state = new_state
# </details>

# %% [markdown]
# Now we can proceed with the implementation. This series of exercises break it down into small steps.
#
# <div class="alert alert-warning">
#
# **Exercise:**
# It will actually be useful to have separate torch.Tensor for each element type in the sampled minibatch.
# That is, one Tensor for a minibatch of states, another for actions, etc.
# Let's redefine the sample function of our replay buffer class to that end.
# </div>

# %%
# %load solutions/RL5_exercise3.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

import random
import torch


class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity # capacity of the buffer
        self.data = []
        self.index = 0 # index of the next cell to be filled

    def append(self, s, a, r, s_, d):
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d)
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size):
        batch = random.sample(self.data, batch_size)
        return [torch.Tensor(np.array(x)).to(device) for x in zip(*batch, strict=True)]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Define a utility function that computes the greedy action from a DQN and a batch of states.
# </div>

# %%
# %load solutions/RL5_exercise4.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

def greedy_action(network, state):
    with torch.no_grad():
        Q = network(  torch.Tensor(state).unsqueeze(0).to(device)  )
        return torch.argmax(Q).item()


def random_action(network, state):
    with torch.no_grad():
        Q = network(  torch.Tensor(state).unsqueeze(0).to(device)  )
        #print(Q)
        nq = len(Q)
        rq = random.randint(0, nq)
        return Q[rq]

# %%
random_action(DQN, [1, 2, 3, 4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 random_action(DQN, [1, 2, 3, 4])
#
# Cell In[19], line 19, in random_action(network, state)
#      17 nq = len(Q)
#      18 rq = random.randint(0, nq)
# ---> 19 return Q[rq]
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Write a class that keeps a replay buffer as internal attribute and implements the pseudo-code you wrote earlier.
# Here are a few tips:
# - To ensure exploration, take a constant $\epsilon_{max}$ value during $\tau_{delay}$ time steps, then substract $\epsilon_{step}$ from $\epsilon$ at every time step until you reach time $\tau_{period}$.
# - A common optimizer (instead of plain SGD) is RMSprop.
# - Assume the interaction with the environment will be episodic. After each training episode store the episode's cumulated return for monitoring.
#
# Write your class but don't run this code just yet!
# </div>

# %%
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).



class DQNAgent:
    def __init__(self, config, model):
        self.gamma = config["gamma"]
        self.batch_size = config["batch_size"]
        self.nb_actions = config["nb_actions"]
        self.memory = ReplayBuffer(config["buffer_size"])
        self.epsilon_max = config["epsilon_max"]
        self.epsilon_min = config["epsilon_min"]
        self.epsilon_stop = config["epsilon_decay_period"]
        self.epsilon_delay = config["epsilon_delay_decay"]
        self.epsilon_step = (self.epsilon_max - self.epsilon_min) / self.epsilon_stop
        self.total_steps = 0
        self.model = model
        self.criterion = torch.nn.MSELoss()
        self.optimizer = torch.optim.RMSprop(
            self.model.parameters(), lr=config["learning_rate"],
        )

    def gradient_step(self):
        if len(self.memory) < self.batch_size:
            return

        # Sample from memory
        X, A, R, Y, D = self.memory.sample(self.batch_size)

        # Compute y_t = r(s, a) + \gamma * max_a' Q(s', a')
        QYmax = self.model(Y).max(1)[0].detach()
        update = torch.addcmul(R, 1 - D, QYmax, value=self.gamma)

        # Compute loss
        QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
        loss = self.criterion(QXA, update.unsqueeze(1))

        # Gradient step
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def train(self, env, max_episode):
        episode_return = []
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0

        while episode < max_episode:
            # Update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon - self.epsilon_step)

            # Select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = np.random.randint(self.nb_actions)
            else:
                action = greedy_action(self.model, state)

            # Step and store in memory
            next_state, reward, done, _, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward

            # Train
            self.gradient_step()

            # Next transition
            step += 1
            if done:
                episode += 1
                print(
                    f"Episode {episode:3d}, epsilon {epsilon:6.2f},",
                    f"batch size {len(self.memory):5d},",
                    f"episode return {episode_cum_reward:4.1f}",
                )
                state, _ = env.reset()
                episode_return.append(episode_cum_reward)
                episode_cum_reward = 0
            else:
                state = next_state

        return episode_return # reward

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Train for 200 episodes on CartPole, with a learning rate of $0.001$, abatch size of $20$, $\gamma=0.95$ and a replay buffer of maximum $1000000$ samples. Take $\epsilon_{max}=1$, $\epsilon_{min=0.01}$, $\tau_{delay}=20$ and $\tau_{period}=1000$.
# </div>

# %%
# %load solutions/RL5_exercise6.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

cartpole = gym.make("CartPole-v1")

config = {  "observation_space": cartpole.observation_space.shape[0],
            "nb_actions": cartpole.action_space.n,
            "learning_rate": 0.001,
            "gamma": 0.95,
            "buffer_size": 1000000,
            "epsilon_min": 0.01,
            "epsilon_max": 1.0,
            "epsilon_decay_period": 1000,
            "epsilon_delay_decay": 20,
            "batch_size": 20}

agent = DQNAgent(config=config, model=DQN)

episode_return = agent.train(env=cartpole, max_episode=500)

plt.figure()
plt.plot(episode_return)
# Out:
# Episode   1, epsilon   1.00, batch size    23, episode return 23.0
# Episode   2, epsilon   0.99, batch size    35, episode return 12.0
# Episode   3, epsilon   0.98, batch size    46, episode return 11.0
# Episode   4, epsilon   0.96, batch size    61, episode return 15.0
# Episode   5, epsilon   0.93, batch size    89, episode return 28.0
# Episode   6, epsilon   0.92, batch size   101, episode return 12.0
# Episode   7, epsilon   0.89, batch size   134, episode return 33.0
# Episode   8, epsilon   0.87, batch size   153, episode return 19.0
# Episode   9, epsilon   0.84, batch size   178, episode return 25.0
# Episode  10, epsilon   0.83, batch size   196, episode return 18.0
# Episode  11, epsilon   0.81, batch size   216, episode return 20.0
# Episode  12, epsilon   0.76, batch size   262, episode return 46.0
# Episode  13, epsilon   0.74, batch size   280, episode return 18.0
# Episode  14, epsilon   0.72, batch size   299, episode return 19.0
# Episode  15, epsilon   0.71, batch size   309, episode return 10.0
# Episode  16, epsilon   0.70, batch size   321, episode return 12.0
# Episode  17, epsilon   0.69, batch size   334, episode return 13.0
# Episode  18, epsilon   0.68, batch size   345, episode return 11.0
# Episode  19, epsilon   0.67, batch size   356, episode return 11.0
# Episode  20, epsilon   0.65, batch size   372, episode return 16.0
# Episode  21, epsilon   0.64, batch size   389, episode return 17.0
# Episode  22, epsilon   0.62, batch size   403, episode return 14.0
# Episode  23, epsilon   0.61, batch size   412, episode return  9.0
# Episode  24, epsilon   0.60, batch size   429, episode return 17.0
# Episode  25, epsilon   0.58, batch size   447, episode return 18.0
# Episode  26, epsilon   0.57, batch size   456, episode return  9.0
# Episode  27, epsilon   0.55, batch size   471, episode return 15.0
# Episode  28, epsilon   0.54, batch size   484, episode return 13.0
# Episode  29, epsilon   0.53, batch size   499, episode return 15.0
# Episode  30, epsilon   0.52, batch size   509, episode return 10.0
# Episode  31, epsilon   0.50, batch size   521, episode return 12.0
# Episode  32, epsilon   0.49, batch size   537, episode return 16.0
# Episode  33, epsilon   0.48, batch size   549, episode return 12.0
# Episode  34, epsilon   0.47, batch size   561, episode return 12.0
# Episode  35, epsilon   0.45, batch size   572, episode return 11.0
# Episode  36, epsilon   0.44, batch size   583, episode return 11.0
# Episode  37, epsilon   0.44, batch size   591, episode return  8.0
# Episode  38, epsilon   0.42, batch size   603, episode return 12.0
# Episode  39, epsilon   0.41, batch size   620, episode return 17.0
# Episode  40, epsilon   0.39, batch size   633, episode return 13.0
# Episode  41, epsilon   0.38, batch size   652, episode return 19.0
# Episode  42, epsilon   0.36, batch size   669, episode return 17.0
# Episode  43, epsilon   0.35, batch size   682, episode return 13.0
# Episode  44, epsilon   0.33, batch size   696, episode return 14.0
# Episode  45, epsilon   0.32, batch size   706, episode return 10.0
# Episode  46, epsilon   0.31, batch size   723, episode return 17.0
# Episode  47, epsilon   0.30, batch size   731, episode return  8.0
# Episode  48, epsilon   0.29, batch size   740, episode return  9.0
# Episode  49, epsilon   0.27, batch size   754, episode return 14.0
# Episode  50, epsilon   0.26, batch size   770, episode return 16.0
# Episode  51, epsilon   0.24, batch size   789, episode return 19.0
# Episode  52, epsilon   0.23, batch size   803, episode return 14.0
# Episode  53, epsilon   0.21, batch size   816, episode return 13.0
# Episode  54, epsilon   0.19, batch size   843, episode return 27.0
# Episode  55, epsilon   0.17, batch size   861, episode return 18.0
# Episode  56, epsilon   0.14, batch size   888, episode return 27.0
# Episode  57, epsilon   0.09, batch size   943, episode return 55.0
# Episode  58, epsilon   0.05, batch size   982, episode return 39.0
# Episode  59, epsilon   0.02, batch size  1012, episode return 30.0
# Episode  60, epsilon   0.01, batch size  1052, episode return 40.0
# Episode  61, epsilon   0.01, batch size  1108, episode return 56.0
# Episode  62, epsilon   0.01, batch size  1145, episode return 37.0
# Episode  63, epsilon   0.01, batch size  1178, episode return 33.0
# Episode  64, epsilon   0.01, batch size  1226, episode return 48.0
# Episode  65, epsilon   0.01, batch size  1249, episode return 23.0
# Episode  66, epsilon   0.01, batch size  1292, episode return 43.0
# Episode  67, epsilon   0.01, batch size  1412, episode return 120.0
# Episode  68, epsilon   0.01, batch size  1446, episode return 34.0
# Episode  69, epsilon   0.01, batch size  1515, episode return 69.0
# Episode  70, epsilon   0.01, batch size  1553, episode return 38.0
# Episode  71, epsilon   0.01, batch size  1713, episode return 160.0
# Episode  72, epsilon   0.01, batch size  1843, episode return 130.0
# Episode  73, epsilon   0.01, batch size  1941, episode return 98.0
# Episode  74, epsilon   0.01, batch size  2003, episode return 62.0
# Episode  75, epsilon   0.01, batch size  2120, episode return 117.0
# Episode  76, epsilon   0.01, batch size  2209, episode return 89.0
# Episode  77, epsilon   0.01, batch size  2310, episode return 101.0
# Episode  78, epsilon   0.01, batch size  2367, episode return 57.0
# Episode  79, epsilon   0.01, batch size  2411, episode return 44.0
# Episode  80, epsilon   0.01, batch size  2474, episode return 63.0
# Episode  81, epsilon   0.01, batch size  2568, episode return 94.0
# Episode  82, epsilon   0.01, batch size  2624, episode return 56.0
# Episode  83, epsilon   0.01, batch size  2732, episode return 108.0
# Episode  84, epsilon   0.01, batch size  2811, episode return 79.0
# Episode  85, epsilon   0.01, batch size  2879, episode return 68.0
# Episode  86, epsilon   0.01, batch size  2985, episode return 106.0
# Episode  87, epsilon   0.01, batch size  3053, episode return 68.0
# Episode  88, epsilon   0.01, batch size  3119, episode return 66.0
# Episode  89, epsilon   0.01, batch size  3167, episode return 48.0
# Episode  90, epsilon   0.01, batch size  3259, episode return 92.0
# Episode  91, epsilon   0.01, batch size  3374, episode return 115.0
# Episode  92, epsilon   0.01, batch size  3427, episode return 53.0
# Episode  93, epsilon   0.01, batch size  3469, episode return 42.0
# Episode  94, epsilon   0.01, batch size  3596, episode return 127.0
# Episode  95, epsilon   0.01, batch size  3681, episode return 85.0
# Episode  96, epsilon   0.01, batch size  3741, episode return 60.0
# Episode  97, epsilon   0.01, batch size  3805, episode return 64.0
# Episode  98, epsilon   0.01, batch size  3872, episode return 67.0
# Episode  99, epsilon   0.01, batch size  3930, episode return 58.0
# Episode 100, epsilon   0.01, batch size  4010, episode return 80.0
# Episode 101, epsilon   0.01, batch size  4068, episode return 58.0
# Episode 102, epsilon   0.01, batch size  4187, episode return 119.0
# Episode 103, epsilon   0.01, batch size  4257, episode return 70.0
# Episode 104, epsilon   0.01, batch size  4355, episode return 98.0
# Episode 105, epsilon   0.01, batch size  4562, episode return 207.0
# Episode 106, epsilon   0.01, batch size  4779, episode return 217.0
# Episode 107, epsilon   0.01, batch size  4879, episode return 100.0
# Episode 108, epsilon   0.01, batch size  4945, episode return 66.0
# Episode 109, epsilon   0.01, batch size  5125, episode return 180.0
# Episode 110, epsilon   0.01, batch size  5237, episode return 112.0
# Episode 111, epsilon   0.01, batch size  5442, episode return 205.0
# Episode 112, epsilon   0.01, batch size  5832, episode return 390.0
# Episode 113, epsilon   0.01, batch size  6050, episode return 218.0
# Episode 114, epsilon   0.01, batch size  6219, episode return 169.0
# Episode 115, epsilon   0.01, batch size  6626, episode return 407.0
# Episode 116, epsilon   0.01, batch size  6874, episode return 248.0
# Episode 117, epsilon   0.01, batch size  7098, episode return 224.0
# Episode 118, epsilon   0.01, batch size  7305, episode return 207.0
# Episode 119, epsilon   0.01, batch size  7490, episode return 185.0
# Episode 120, epsilon   0.01, batch size  7658, episode return 168.0
# Episode 121, epsilon   0.01, batch size  7913, episode return 255.0
# Episode 122, epsilon   0.01, batch size  8110, episode return 197.0
# Episode 123, epsilon   0.01, batch size  8367, episode return 257.0
# Episode 124, epsilon   0.01, batch size  8767, episode return 400.0
# Episode 125, epsilon   0.01, batch size  9000, episode return 233.0
# Episode 126, epsilon   0.01, batch size  9199, episode return 199.0
# Episode 127, epsilon   0.01, batch size  9485, episode return 286.0
# Episode 128, epsilon   0.01, batch size  9723, episode return 238.0
# Episode 129, epsilon   0.01, batch size  9986, episode return 263.0
# Episode 130, epsilon   0.01, batch size 10201, episode return 215.0
# Episode 131, epsilon   0.01, batch size 10462, episode return 261.0
# Episode 132, epsilon   0.01, batch size 10703, episode return 241.0
# Episode 133, epsilon   0.01, batch size 10911, episode return 208.0
# Episode 134, epsilon   0.01, batch size 11093, episode return 182.0
# Episode 135, epsilon   0.01, batch size 11261, episode return 168.0
# Episode 136, epsilon   0.01, batch size 11463, episode return 202.0
# Episode 137, epsilon   0.01, batch size 11691, episode return 228.0
# Episode 138, epsilon   0.01, batch size 11894, episode return 203.0
# Episode 139, epsilon   0.01, batch size 12103, episode return 209.0
# Episode 140, epsilon   0.01, batch size 12307, episode return 204.0
# Episode 141, epsilon   0.01, batch size 12614, episode return 307.0
# Episode 142, epsilon   0.01, batch size 12913, episode return 299.0
# Episode 143, epsilon   0.01, batch size 13264, episode return 351.0
# Episode 144, epsilon   0.01, batch size 13521, episode return 257.0
# Episode 145, epsilon   0.01, batch size 13741, episode return 220.0
# Episode 146, epsilon   0.01, batch size 13967, episode return 226.0
# Episode 147, epsilon   0.01, batch size 14136, episode return 169.0
# Episode 148, epsilon   0.01, batch size 14332, episode return 196.0
# Episode 149, epsilon   0.01, batch size 14526, episode return 194.0
# Episode 150, epsilon   0.01, batch size 14815, episode return 289.0
# Episode 151, epsilon   0.01, batch size 15049, episode return 234.0
# Episode 152, epsilon   0.01, batch size 15330, episode return 281.0
# Episode 153, epsilon   0.01, batch size 15568, episode return 238.0
# Episode 154, epsilon   0.01, batch size 15845, episode return 277.0
# Episode 155, epsilon   0.01, batch size 16066, episode return 221.0
# Episode 156, epsilon   0.01, batch size 16253, episode return 187.0
# Episode 157, epsilon   0.01, batch size 16474, episode return 221.0
# Episode 158, epsilon   0.01, batch size 16676, episode return 202.0
# Episode 159, epsilon   0.01, batch size 16976, episode return 300.0
# Episode 160, epsilon   0.01, batch size 17211, episode return 235.0
# Episode 161, epsilon   0.01, batch size 17448, episode return 237.0
# Episode 162, epsilon   0.01, batch size 17710, episode return 262.0
# Episode 163, epsilon   0.01, batch size 17936, episode return 226.0
# Episode 164, epsilon   0.01, batch size 18188, episode return 252.0
# Episode 165, epsilon   0.01, batch size 18364, episode return 176.0
# Episode 166, epsilon   0.01, batch size 18622, episode return 258.0
# Episode 167, epsilon   0.01, batch size 18811, episode return 189.0
# Episode 168, epsilon   0.01, batch size 19003, episode return 192.0
# Episode 169, epsilon   0.01, batch size 19225, episode return 222.0
# Episode 170, epsilon   0.01, batch size 19601, episode return 376.0
# Episode 171, epsilon   0.01, batch size 19812, episode return 211.0
# Episode 172, epsilon   0.01, batch size 20002, episode return 190.0
# Episode 173, epsilon   0.01, batch size 20202, episode return 200.0
# Episode 174, epsilon   0.01, batch size 20435, episode return 233.0
# Episode 175, epsilon   0.01, batch size 20700, episode return 265.0
# Episode 176, epsilon   0.01, batch size 20929, episode return 229.0
# Episode 177, epsilon   0.01, batch size 21136, episode return 207.0
# Episode 178, epsilon   0.01, batch size 21329, episode return 193.0
# Episode 179, epsilon   0.01, batch size 21513, episode return 184.0
# Episode 180, epsilon   0.01, batch size 21749, episode return 236.0
# Episode 181, epsilon   0.01, batch size 21991, episode return 242.0
# Episode 182, epsilon   0.01, batch size 22149, episode return 158.0
# Episode 183, epsilon   0.01, batch size 22360, episode return 211.0
# Episode 184, epsilon   0.01, batch size 22552, episode return 192.0
# Episode 185, epsilon   0.01, batch size 22754, episode return 202.0
# Episode 186, epsilon   0.01, batch size 23039, episode return 285.0
# Episode 187, epsilon   0.01, batch size 23262, episode return 223.0
# Episode 188, epsilon   0.01, batch size 23461, episode return 199.0
# Episode 189, epsilon   0.01, batch size 23674, episode return 213.0
# Episode 190, epsilon   0.01, batch size 23873, episode return 199.0
# Episode 191, epsilon   0.01, batch size 24169, episode return 296.0
# Episode 192, epsilon   0.01, batch size 24367, episode return 198.0
# Episode 193, epsilon   0.01, batch size 24562, episode return 195.0
# Episode 194, epsilon   0.01, batch size 24815, episode return 253.0
# Episode 195, epsilon   0.01, batch size 25007, episode return 192.0
# Episode 196, epsilon   0.01, batch size 25192, episode return 185.0
# Episode 197, epsilon   0.01, batch size 25396, episode return 204.0
# Episode 198, epsilon   0.01, batch size 25614, episode return 218.0
# Episode 199, epsilon   0.01, batch size 25811, episode return 197.0
# Episode 200, epsilon   0.01, batch size 26020, episode return 209.0
# Episode 201, epsilon   0.01, batch size 26264, episode return 244.0
# Episode 202, epsilon   0.01, batch size 26512, episode return 248.0
# Episode 203, epsilon   0.01, batch size 26737, episode return 225.0
# Episode 204, epsilon   0.01, batch size 26957, episode return 220.0
# Episode 205, epsilon   0.01, batch size 27163, episode return 206.0
# Episode 206, epsilon   0.01, batch size 27395, episode return 232.0
# Episode 207, epsilon   0.01, batch size 27629, episode return 234.0
# Episode 208, epsilon   0.01, batch size 27909, episode return 280.0
# Episode 209, epsilon   0.01, batch size 28168, episode return 259.0
# Episode 210, epsilon   0.01, batch size 28394, episode return 226.0
# Episode 211, epsilon   0.01, batch size 28602, episode return 208.0
# Episode 212, epsilon   0.01, batch size 28814, episode return 212.0
# Episode 213, epsilon   0.01, batch size 29002, episode return 188.0
# Episode 214, epsilon   0.01, batch size 29188, episode return 186.0
# Episode 215, epsilon   0.01, batch size 29391, episode return 203.0
# Episode 216, epsilon   0.01, batch size 29574, episode return 183.0
# Episode 217, epsilon   0.01, batch size 29858, episode return 284.0
# Episode 218, epsilon   0.01, batch size 30089, episode return 231.0
# Episode 219, epsilon   0.01, batch size 30270, episode return 181.0
# Episode 220, epsilon   0.01, batch size 30505, episode return 235.0
# Episode 221, epsilon   0.01, batch size 30724, episode return 219.0
# Episode 222, epsilon   0.01, batch size 30981, episode return 257.0
# Episode 223, epsilon   0.01, batch size 31178, episode return 197.0
# Episode 224, epsilon   0.01, batch size 31403, episode return 225.0
# Episode 225, epsilon   0.01, batch size 31623, episode return 220.0
# Episode 226, epsilon   0.01, batch size 31886, episode return 263.0
# Episode 227, epsilon   0.01, batch size 32392, episode return 506.0
# Episode 228, epsilon   0.01, batch size 32593, episode return 201.0
# Episode 229, epsilon   0.01, batch size 32874, episode return 281.0
# Episode 230, epsilon   0.01, batch size 33120, episode return 246.0
# Episode 231, epsilon   0.01, batch size 33559, episode return 439.0
# Episode 232, epsilon   0.01, batch size 33803, episode return 244.0
# Episode 233, epsilon   0.01, batch size 34108, episode return 305.0
# Episode 234, epsilon   0.01, batch size 34309, episode return 201.0
# Episode 235, epsilon   0.01, batch size 34580, episode return 271.0
# Episode 236, epsilon   0.01, batch size 34786, episode return 206.0
# Episode 237, epsilon   0.01, batch size 35008, episode return 222.0
# Episode 238, epsilon   0.01, batch size 35218, episode return 210.0
# Episode 239, epsilon   0.01, batch size 35573, episode return 355.0
# Episode 240, epsilon   0.01, batch size 35746, episode return 173.0
# Episode 241, epsilon   0.01, batch size 35961, episode return 215.0
# Episode 242, epsilon   0.01, batch size 36175, episode return 214.0
# Episode 243, epsilon   0.01, batch size 36404, episode return 229.0
# Episode 244, epsilon   0.01, batch size 36658, episode return 254.0
# Episode 245, epsilon   0.01, batch size 37003, episode return 345.0
# Episode 246, epsilon   0.01, batch size 37241, episode return 238.0
# Episode 247, epsilon   0.01, batch size 37489, episode return 248.0
# Episode 248, epsilon   0.01, batch size 37694, episode return 205.0
# Episode 249, epsilon   0.01, batch size 37939, episode return 245.0
# Episode 250, epsilon   0.01, batch size 38249, episode return 310.0
# Episode 251, epsilon   0.01, batch size 38450, episode return 201.0
# Episode 252, epsilon   0.01, batch size 38683, episode return 233.0
# Episode 253, epsilon   0.01, batch size 38977, episode return 294.0
# Episode 254, epsilon   0.01, batch size 39193, episode return 216.0
# Episode 255, epsilon   0.01, batch size 39500, episode return 307.0
# Episode 256, epsilon   0.01, batch size 39712, episode return 212.0
# Episode 257, epsilon   0.01, batch size 39917, episode return 205.0
# Episode 258, epsilon   0.01, batch size 40116, episode return 199.0
# Episode 259, epsilon   0.01, batch size 40315, episode return 199.0
# Episode 260, epsilon   0.01, batch size 40527, episode return 212.0
# Episode 261, epsilon   0.01, batch size 40716, episode return 189.0
# Episode 262, epsilon   0.01, batch size 40900, episode return 184.0
# Episode 263, epsilon   0.01, batch size 41088, episode return 188.0
# Episode 264, epsilon   0.01, batch size 41356, episode return 268.0
# Episode 265, epsilon   0.01, batch size 41552, episode return 196.0
# Episode 266, epsilon   0.01, batch size 41757, episode return 205.0
# Episode 267, epsilon   0.01, batch size 41955, episode return 198.0
# Episode 268, epsilon   0.01, batch size 42126, episode return 171.0
# Episode 269, epsilon   0.01, batch size 42319, episode return 193.0
# Episode 270, epsilon   0.01, batch size 42481, episode return 162.0
# Episode 271, epsilon   0.01, batch size 42644, episode return 163.0
# Episode 272, epsilon   0.01, batch size 42802, episode return 158.0
# Episode 273, epsilon   0.01, batch size 43037, episode return 235.0
# Episode 274, epsilon   0.01, batch size 43243, episode return 206.0
# Episode 275, epsilon   0.01, batch size 43436, episode return 193.0
# Episode 276, epsilon   0.01, batch size 43669, episode return 233.0
# Episode 277, epsilon   0.01, batch size 43916, episode return 247.0
# Episode 278, epsilon   0.01, batch size 44149, episode return 233.0
# Episode 279, epsilon   0.01, batch size 44315, episode return 166.0
# Episode 280, epsilon   0.01, batch size 44505, episode return 190.0
# Episode 281, epsilon   0.01, batch size 44907, episode return 402.0
# Episode 282, epsilon   0.01, batch size 45110, episode return 203.0
# Episode 283, epsilon   0.01, batch size 45330, episode return 220.0
# Episode 284, epsilon   0.01, batch size 45577, episode return 247.0
# Episode 285, epsilon   0.01, batch size 45896, episode return 319.0
# Episode 286, epsilon   0.01, batch size 46146, episode return 250.0
# Episode 287, epsilon   0.01, batch size 46373, episode return 227.0
# Episode 288, epsilon   0.01, batch size 46588, episode return 215.0
# Episode 289, epsilon   0.01, batch size 46730, episode return 142.0
# Episode 290, epsilon   0.01, batch size 46914, episode return 184.0
# Episode 291, epsilon   0.01, batch size 47079, episode return 165.0
# Episode 292, epsilon   0.01, batch size 47251, episode return 172.0
# Episode 293, epsilon   0.01, batch size 47458, episode return 207.0
# Episode 294, epsilon   0.01, batch size 47658, episode return 200.0
# Episode 295, epsilon   0.01, batch size 47883, episode return 225.0
# Episode 296, epsilon   0.01, batch size 48109, episode return 226.0
# Episode 297, epsilon   0.01, batch size 48278, episode return 169.0
# Episode 298, epsilon   0.01, batch size 48427, episode return 149.0
# Episode 299, epsilon   0.01, batch size 48612, episode return 185.0
# Episode 300, epsilon   0.01, batch size 48809, episode return 197.0
# Episode 301, epsilon   0.01, batch size 49044, episode return 235.0
# Episode 302, epsilon   0.01, batch size 49244, episode return 200.0
# Episode 303, epsilon   0.01, batch size 49412, episode return 168.0
# Episode 304, epsilon   0.01, batch size 49576, episode return 164.0
# Episode 305, epsilon   0.01, batch size 49712, episode return 136.0
# Episode 306, epsilon   0.01, batch size 49960, episode return 248.0
# Episode 307, epsilon   0.01, batch size 50111, episode return 151.0
# Episode 308, epsilon   0.01, batch size 50451, episode return 340.0
# Episode 309, epsilon   0.01, batch size 50621, episode return 170.0
# Episode 310, epsilon   0.01, batch size 51318, episode return 697.0
# Episode 311, epsilon   0.01, batch size 51479, episode return 161.0
# Episode 312, epsilon   0.01, batch size 51704, episode return 225.0
# Episode 313, epsilon   0.01, batch size 51894, episode return 190.0
# Episode 314, epsilon   0.01, batch size 52257, episode return 363.0
# Episode 315, epsilon   0.01, batch size 52444, episode return 187.0
# Episode 316, epsilon   0.01, batch size 52706, episode return 262.0
# Episode 317, epsilon   0.01, batch size 52917, episode return 211.0
# Episode 318, epsilon   0.01, batch size 53047, episode return 130.0
# Episode 319, epsilon   0.01, batch size 53245, episode return 198.0
# Episode 320, epsilon   0.01, batch size 53454, episode return 209.0
# Episode 321, epsilon   0.01, batch size 53645, episode return 191.0
# Episode 322, epsilon   0.01, batch size 53822, episode return 177.0
# Episode 323, epsilon   0.01, batch size 53997, episode return 175.0
# Episode 324, epsilon   0.01, batch size 54164, episode return 167.0
# Episode 325, epsilon   0.01, batch size 54371, episode return 207.0
# Episode 326, epsilon   0.01, batch size 54532, episode return 161.0
# Episode 327, epsilon   0.01, batch size 54681, episode return 149.0
# Episode 328, epsilon   0.01, batch size 54941, episode return 260.0
# Episode 329, epsilon   0.01, batch size 55101, episode return 160.0
# Episode 330, epsilon   0.01, batch size 55266, episode return 165.0
# Episode 331, epsilon   0.01, batch size 55443, episode return 177.0
# Episode 332, epsilon   0.01, batch size 55595, episode return 152.0
# Episode 333, epsilon   0.01, batch size 55932, episode return 337.0
# Episode 334, epsilon   0.01, batch size 56077, episode return 145.0
# Episode 335, epsilon   0.01, batch size 56237, episode return 160.0
# Episode 336, epsilon   0.01, batch size 56743, episode return 506.0
# Episode 337, epsilon   0.01, batch size 56860, episode return 117.0
# Episode 338, epsilon   0.01, batch size 56997, episode return 137.0
# Episode 339, epsilon   0.01, batch size 57207, episode return 210.0
# Episode 340, epsilon   0.01, batch size 57345, episode return 138.0
# Episode 341, epsilon   0.01, batch size 57503, episode return 158.0
# Episode 342, epsilon   0.01, batch size 57864, episode return 361.0
# Episode 343, epsilon   0.01, batch size 58004, episode return 140.0
# Episode 344, epsilon   0.01, batch size 58142, episode return 138.0
# Episode 345, epsilon   0.01, batch size 58306, episode return 164.0
# Episode 346, epsilon   0.01, batch size 58653, episode return 347.0
# Episode 347, epsilon   0.01, batch size 58784, episode return 131.0
# Episode 348, epsilon   0.01, batch size 58962, episode return 178.0
# Episode 349, epsilon   0.01, batch size 59093, episode return 131.0
# Episode 350, epsilon   0.01, batch size 59256, episode return 163.0
# Episode 351, epsilon   0.01, batch size 59474, episode return 218.0
# Episode 352, epsilon   0.01, batch size 59618, episode return 144.0
# Episode 353, epsilon   0.01, batch size 59776, episode return 158.0
# Episode 354, epsilon   0.01, batch size 59959, episode return 183.0
# Episode 355, epsilon   0.01, batch size 60091, episode return 132.0
# Episode 356, epsilon   0.01, batch size 60211, episode return 120.0
# Episode 357, epsilon   0.01, batch size 60362, episode return 151.0
# Episode 358, epsilon   0.01, batch size 60595, episode return 233.0
# Episode 359, epsilon   0.01, batch size 60759, episode return 164.0
# Episode 360, epsilon   0.01, batch size 60960, episode return 201.0
# Episode 361, epsilon   0.01, batch size 61107, episode return 147.0
# Episode 362, epsilon   0.01, batch size 61434, episode return 327.0
# Episode 363, epsilon   0.01, batch size 61577, episode return 143.0
# Episode 364, epsilon   0.01, batch size 61766, episode return 189.0
# Episode 365, epsilon   0.01, batch size 61994, episode return 228.0
# Episode 366, epsilon   0.01, batch size 62136, episode return 142.0
# Episode 367, epsilon   0.01, batch size 62269, episode return 133.0
# Episode 368, epsilon   0.01, batch size 62409, episode return 140.0
# Episode 369, epsilon   0.01, batch size 62627, episode return 218.0
# Episode 370, epsilon   0.01, batch size 62801, episode return 174.0
# Episode 371, epsilon   0.01, batch size 63008, episode return 207.0
# Episode 372, epsilon   0.01, batch size 63234, episode return 226.0
# Episode 373, epsilon   0.01, batch size 63422, episode return 188.0
# Episode 374, epsilon   0.01, batch size 63629, episode return 207.0
# Episode 375, epsilon   0.01, batch size 63748, episode return 119.0
# Episode 376, epsilon   0.01, batch size 63891, episode return 143.0
# Episode 377, epsilon   0.01, batch size 64046, episode return 155.0
# Episode 378, epsilon   0.01, batch size 64262, episode return 216.0
# Episode 379, epsilon   0.01, batch size 64463, episode return 201.0
# Episode 380, epsilon   0.01, batch size 64591, episode return 128.0
# Episode 381, epsilon   0.01, batch size 64822, episode return 231.0
# Episode 382, epsilon   0.01, batch size 65023, episode return 201.0
# Episode 383, epsilon   0.01, batch size 65158, episode return 135.0
# Episode 384, epsilon   0.01, batch size 65304, episode return 146.0
# Episode 385, epsilon   0.01, batch size 65479, episode return 175.0
# Episode 386, epsilon   0.01, batch size 65630, episode return 151.0
# Episode 387, epsilon   0.01, batch size 65740, episode return 110.0
# Episode 388, epsilon   0.01, batch size 65883, episode return 143.0
# Episode 389, epsilon   0.01, batch size 66136, episode return 253.0
# Episode 390, epsilon   0.01, batch size 66301, episode return 165.0
# Episode 391, epsilon   0.01, batch size 66507, episode return 206.0
# Episode 392, epsilon   0.01, batch size 66783, episode return 276.0
# Episode 393, epsilon   0.01, batch size 66989, episode return 206.0
# Episode 394, epsilon   0.01, batch size 67259, episode return 270.0
# Episode 395, epsilon   0.01, batch size 67547, episode return 288.0
# Episode 396, epsilon   0.01, batch size 67756, episode return 209.0
# Episode 397, epsilon   0.01, batch size 67894, episode return 138.0
# Episode 398, epsilon   0.01, batch size 68125, episode return 231.0
# Episode 399, epsilon   0.01, batch size 68256, episode return 131.0
# Episode 400, epsilon   0.01, batch size 68604, episode return 348.0
# Episode 401, epsilon   0.01, batch size 68808, episode return 204.0
# Episode 402, epsilon   0.01, batch size 68965, episode return 157.0
# Episode 403, epsilon   0.01, batch size 69117, episode return 152.0
# Episode 404, epsilon   0.01, batch size 69350, episode return 233.0
# Episode 405, epsilon   0.01, batch size 69472, episode return 122.0
# Episode 406, epsilon   0.01, batch size 69751, episode return 279.0
# Episode 407, epsilon   0.01, batch size 70068, episode return 317.0
# Episode 408, epsilon   0.01, batch size 70170, episode return 102.0
# Episode 409, epsilon   0.01, batch size 70280, episode return 110.0
# Episode 410, epsilon   0.01, batch size 70495, episode return 215.0
# Episode 411, epsilon   0.01, batch size 70729, episode return 234.0
# Episode 412, epsilon   0.01, batch size 71019, episode return 290.0
# Episode 413, epsilon   0.01, batch size 71162, episode return 143.0
# Episode 414, epsilon   0.01, batch size 71296, episode return 134.0
# Episode 415, epsilon   0.01, batch size 71426, episode return 130.0
# Episode 416, epsilon   0.01, batch size 71673, episode return 247.0
# Episode 417, epsilon   0.01, batch size 71945, episode return 272.0
# Episode 418, epsilon   0.01, batch size 72159, episode return 214.0
# Episode 419, epsilon   0.01, batch size 72357, episode return 198.0
# Episode 420, epsilon   0.01, batch size 72523, episode return 166.0
# Episode 421, epsilon   0.01, batch size 72987, episode return 464.0
# Episode 422, epsilon   0.01, batch size 73246, episode return 259.0
# Episode 423, epsilon   0.01, batch size 73474, episode return 228.0
# Episode 424, epsilon   0.01, batch size 73654, episode return 180.0
# Episode 425, epsilon   0.01, batch size 73813, episode return 159.0
# Episode 426, epsilon   0.01, batch size 73927, episode return 114.0
# Episode 427, epsilon   0.01, batch size 74118, episode return 191.0
# Episode 428, epsilon   0.01, batch size 74311, episode return 193.0
# Episode 429, epsilon   0.01, batch size 74563, episode return 252.0
# Episode 430, epsilon   0.01, batch size 74736, episode return 173.0
# Episode 431, epsilon   0.01, batch size 75005, episode return 269.0
# Episode 432, epsilon   0.01, batch size 75675, episode return 670.0
# Episode 433, epsilon   0.01, batch size 75956, episode return 281.0
# Episode 434, epsilon   0.01, batch size 76121, episode return 165.0
# Episode 435, epsilon   0.01, batch size 76281, episode return 160.0
# Episode 436, epsilon   0.01, batch size 76543, episode return 262.0
# Episode 437, epsilon   0.01, batch size 76698, episode return 155.0
# Episode 438, epsilon   0.01, batch size 76867, episode return 169.0
# Episode 439, epsilon   0.01, batch size 77069, episode return 202.0
# Episode 440, epsilon   0.01, batch size 77200, episode return 131.0
# Episode 441, epsilon   0.01, batch size 77668, episode return 468.0
# Episode 442, epsilon   0.01, batch size 77898, episode return 230.0
# Episode 443, epsilon   0.01, batch size 78088, episode return 190.0
# Episode 444, epsilon   0.01, batch size 78311, episode return 223.0
# Episode 445, epsilon   0.01, batch size 78514, episode return 203.0
# Episode 446, epsilon   0.01, batch size 78804, episode return 290.0
# Episode 447, epsilon   0.01, batch size 79140, episode return 336.0
# Episode 448, epsilon   0.01, batch size 79352, episode return 212.0
# Episode 449, epsilon   0.01, batch size 79515, episode return 163.0
# Episode 450, epsilon   0.01, batch size 79733, episode return 218.0
# Episode 451, epsilon   0.01, batch size 79944, episode return 211.0
# Episode 452, epsilon   0.01, batch size 80098, episode return 154.0
# Episode 453, epsilon   0.01, batch size 80331, episode return 233.0
# Episode 454, epsilon   0.01, batch size 80573, episode return 242.0
# Episode 455, epsilon   0.01, batch size 80876, episode return 303.0
# Episode 456, epsilon   0.01, batch size 81376, episode return 500.0
# Episode 457, epsilon   0.01, batch size 81531, episode return 155.0
# Episode 458, epsilon   0.01, batch size 81728, episode return 197.0
# Episode 459, epsilon   0.01, batch size 81912, episode return 184.0
# Episode 460, epsilon   0.01, batch size 82125, episode return 213.0
# Episode 461, epsilon   0.01, batch size 82395, episode return 270.0
# Episode 462, epsilon   0.01, batch size 82562, episode return 167.0
# Episode 463, epsilon   0.01, batch size 82728, episode return 166.0
# Episode 464, epsilon   0.01, batch size 82967, episode return 239.0
# Episode 465, epsilon   0.01, batch size 83142, episode return 175.0
# Episode 466, epsilon   0.01, batch size 83460, episode return 318.0
# Episode 467, epsilon   0.01, batch size 83847, episode return 387.0
# Episode 468, epsilon   0.01, batch size 84182, episode return 335.0
# Episode 469, epsilon   0.01, batch size 84317, episode return 135.0
# Episode 470, epsilon   0.01, batch size 84552, episode return 235.0
# Episode 471, epsilon   0.01, batch size 84796, episode return 244.0
# Episode 472, epsilon   0.01, batch size 85047, episode return 251.0
# Episode 473, epsilon   0.01, batch size 85212, episode return 165.0
# Episode 474, epsilon   0.01, batch size 85349, episode return 137.0
# Episode 475, epsilon   0.01, batch size 85551, episode return 202.0
# Episode 476, epsilon   0.01, batch size 85999, episode return 448.0
# Episode 477, epsilon   0.01, batch size 86231, episode return 232.0
# Episode 478, epsilon   0.01, batch size 86402, episode return 171.0
# Episode 479, epsilon   0.01, batch size 86517, episode return 115.0
# Episode 480, epsilon   0.01, batch size 86786, episode return 269.0
# Episode 481, epsilon   0.01, batch size 86989, episode return 203.0
# Episode 482, epsilon   0.01, batch size 87132, episode return 143.0
# Episode 483, epsilon   0.01, batch size 87270, episode return 138.0
# Episode 484, epsilon   0.01, batch size 87418, episode return 148.0
# Episode 485, epsilon   0.01, batch size 87616, episode return 198.0
# Episode 486, epsilon   0.01, batch size 87772, episode return 156.0
# Episode 487, epsilon   0.01, batch size 88349, episode return 577.0
# Episode 488, epsilon   0.01, batch size 88549, episode return 200.0
# Episode 489, epsilon   0.01, batch size 88714, episode return 165.0
# Episode 490, epsilon   0.01, batch size 88830, episode return 116.0
# Episode 491, epsilon   0.01, batch size 88957, episode return 127.0
# Episode 492, epsilon   0.01, batch size 89086, episode return 129.0
# Episode 493, epsilon   0.01, batch size 89200, episode return 114.0
# Episode 494, epsilon   0.01, batch size 89386, episode return 186.0
# Episode 495, epsilon   0.01, batch size 89520, episode return 134.0
# Episode 496, epsilon   0.01, batch size 89703, episode return 183.0
# Episode 497, epsilon   0.01, batch size 89851, episode return 148.0
# Episode 498, epsilon   0.01, batch size 90487, episode return 636.0
# Episode 499, epsilon   0.01, batch size 90756, episode return 269.0
# Episode 500, epsilon   0.01, batch size 90989, episode return 233.0

# %%
cartpole = gym.make("CartPole-v1", render_mode="human")

s, _ = cartpole.reset()
for i in range(1000):
    a = (DQN, s)
    s, _, d, _, _ = cartpole.step(a)
    if d:
        print("Final nb steps:", i)
        break

cartpole.close()

# %% [markdown]
# # <div id="tricks"></div>Making DQN more efficient

# %% [markdown]
# ## <div id="optimizer"></div>Changing the optimizer
#
# The question of which optimizer to choose is quite open in RL. Most common choices are RMSprop or Adam (with, sometimes, carefully chosen hyperparameters). For the example of CartPole, it seems Adam with default parameters works better, but that's not a general rule.

# %% [markdown]
# ## <div id="nb-grad-steps"></div>Several gradient steps
#
# Recall that within an iteration of Value Iteration, one aims at minimizing the $L_n(\theta)$ (before moving on to the next iteration). Why take a single gradient step on this loss when a new sample is collected? Taking several gradient steps can greatly accelerate the convergence in terms of number of collected samples. That's what is commonly called *sample efficiency*.

# %% [markdown]
# ## <div id="target-networks"></div>Target network
#
# It appears the code above will (probably) slowly converge to $Q^*$ but this convergence might be unstable and noisy. This can be greatly improved by taking several gradient steps on a given loss function $L_n$ instead of changing the loss function after each sample. This idea is similar to the one above. And is the same as that of delayed updates that we introduced in the class on temporal difference learning.
#
# In practice, this is achieved by the introduction of a *target network* whose parameters are noted $\theta^-$. This idea for DQN was introduced in the **[Human-level control through deep reinforcement learning](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning)** paper. At any time step, the loss becomes:
# $$L(\theta) = \mathbb{E}_{s,a,r,s'} \left[ \left( r + \gamma \max_{a'} Q(s',a',\theta^-) - Q(s,a;\theta) \right) ^2 \right],$$
# and the target network parameters $\theta^-$ are only updated with the Q-network parameters $\theta_n$ every $C$ steps and are held fixed between individual updates.
#
# This process of accumulating several gradient steps into $\theta_n$ before updating $\theta^-$ draws our algorithm closer to a Value Iteration scheme (or a Fitted Q-Iteration scheme for that matter).
#
# Note that more recent approaches smooth out this accumulation process by defining soft updates of the form:
# $$\theta^- \leftarrow \beta \theta^- + (1-\beta) \theta_n.$$

# %% [markdown]
# <span style="color:#3566B9">
#
# On fige une copie de notre réseau pour entraîner le réseau. Dès que le réseau est devenu meilleur, on remplace son ex-copie.
#
# Cette technique est un grand classique.

# %% [markdown]
# ## <div id="error-clipping"></div>Error clipping
#
# Another common pratice to stabilize learning is to clip the value of the loss' gradient between $-1$ and $1$. This is not such an uncommon trick, it actually amounts to using an L2 loss for values of the loss between $-1$ and $1$ and an L1 loss outside of this domain. This is also know as the [Huber Loss](https://en.wikipedia.org/wiki/Huber_loss) or the [smooth L1 loss](https://pytorch.org/docs/stable/nn.html#smoothl1loss).

# %% [markdown]
# <span style="color:#3566B9">
#
# Ce clipage du gradient est utile parce qu'on utilise un échantillonnage pour l'estimer. Notre estimation peut être un peu malchanceuse, et surestimer le gradient. En le clippant, on s'assure qu'il ne va pas exploser par inadvertance.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Modify you code from the previous exercises to include a target network (with $C$ in the order of $100$), a fixed number of gradient steps per acquired sample, and the clipping of the error term. You can also use Adam for improved efficiency.
# </div>

# %%
# %load solutions/RL5_exercise7.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).


from copy import deepcopy

class DQNAgent:
    def __init__(self, config, model):
        self.gamma = config["gamma"]
        self.batch_size = config["batch_size"]
        self.nb_actions = config["nb_actions"]
        self.memory = ReplayBuffer(config["buffer_size"])
        self.epsilon_max = config["epsilon_max"]
        self.epsilon_min = config["epsilon_min"]
        self.epsilon_stop = config["epsilon_decay_period"]
        self.epsilon_delay = config["epsilon_delay_decay"]
        self.epsilon_step = (self.epsilon_max - self.epsilon_min) / self.epsilon_stop
        self.nb_gradient_steps = config["gradient_steps"]  # NEW NEW NEW
        self.total_steps = 0
        self.model = model
        
        self.criterion = torch.nn.SmoothL1Loss()  # NEW NEW NEW
        self.optimizer = torch.optim.Adam(
            self.model.parameters(), lr=config["learning_rate"]
        )  # NEW NEW NEW
        self.target_model = deepcopy(self.model).to(device)  # NEW NEW NEW
        self.update_target_freq = config["update_target_freq"]  # NEW NEW NEW

    def gradient_step(self):
        if len(self.memory) < self.batch_size:
            return

        # Sample from memory
        X, A, R, Y, D = self.memory.sample(self.batch_size)

        # Compute y_t = r(s, a) + \gamma * max_a' Q(s', a')
        QYmax = self.target_model(Y).max(1)[0].detach()
        update = torch.addcmul(R, 1 - D, QYmax, value=self.gamma)

        # Compute loss
        QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
        loss = self.criterion(QXA, update.unsqueeze(1))

        # Gradient step
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def train(self, env, max_episode):
        episode_return = []
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0

        while episode < max_episode:
            # Update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon - self.epsilon_step)

            # Select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = np.random.randint(self.nb_actions)
            else:
                action = greedy_action(self.model, state)

            # Step and store in memory
            next_state, reward, done, _, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward

            # Train
            for _ in range(self.nb_gradient_steps): # NEW NEW NEW
                self.gradient_step()

            # update target network if needed
            if step % self.update_target_freq == 0: # NEW NEW NEW
                self.target_model.load_state_dict(self.model.state_dict())

            # Next transition
            step += 1
            if done:
                episode += 1
                print(
                    f"Episode {episode:3d}, epsilon {epsilon:6.2f},",
                    f"batch size {len(self.memory):5d},",
                    f"episode return {episode_cum_reward:4.1f}",
                )
                state, _ = env.reset()
                episode_return.append(episode_cum_reward)
                episode_cum_reward = 0
            else:
                state = next_state

        return episode_return

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Run your code to learn an efficient policy for CartPole. Don't forget to reset the network before you start learning.
# </div>

# %%
# %load solutions/RL5_exercise8.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

# Let's reset the Q function

import torch
import torch.nn as nn
import gymnasium as gym

cartpole = gym.make("CartPole-v1")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

state_dim = cartpole.observation_space.shape[0]
n_action = cartpole.action_space.n
nb_neurons = 24

# reset the Q function
DQN = torch.nn.Sequential(
    nn.Linear(state_dim, nb_neurons),
    nn.ReLU(),
    nn.Linear(nb_neurons, nb_neurons),
    nn.ReLU(),
    nn.Linear(nb_neurons, n_action),
).to(device)

config = {
    "observation_space": cartpole.observation_space.shape[0],
    "nb_actions": cartpole.action_space.n,
    "learning_rate": 0.001,
    "gamma": 0.95,
    "buffer_size": 1000000,
    "epsilon_min": 0.01,
    "epsilon_max": 1.0,
    "epsilon_decay_period": 1000,
    "epsilon_delay_decay": 20,
    "batch_size": 20,
    "gradient_steps": 10,
    "update_target_freq": 100,
}

agent = DQNAgent(config, DQN)
scores = agent.train(cartpole, 100)

plt.plot(scores)
torch.save(DQN.state_dict(), "cart_pole_dqn.pth")
# Out:
# Episode   1, epsilon   0.99, batch size    27, episode return 27.0
# Episode   2, epsilon   0.98, batch size    42, episode return 15.0
# Episode   3, epsilon   0.96, batch size    63, episode return 21.0
# Episode   4, epsilon   0.95, batch size    72, episode return  9.0
# Episode   5, epsilon   0.94, batch size    83, episode return 11.0
# Episode   6, epsilon   0.90, batch size   122, episode return 39.0
# Episode   7, epsilon   0.89, batch size   132, episode return 10.0
# Episode   8, epsilon   0.88, batch size   142, episode return 10.0
# Episode   9, epsilon   0.87, batch size   154, episode return 12.0
# Episode  10, epsilon   0.85, batch size   176, episode return 22.0
# Episode  11, epsilon   0.83, batch size   196, episode return 20.0
# Episode  12, epsilon   0.81, batch size   211, episode return 15.0
# Episode  13, epsilon   0.80, batch size   226, episode return 15.0
# Episode  14, epsilon   0.78, batch size   240, episode return 14.0
# Episode  15, epsilon   0.76, batch size   262, episode return 22.0
# Episode  16, epsilon   0.75, batch size   277, episode return 15.0
# Episode  17, epsilon   0.71, batch size   309, episode return 32.0
# Episode  18, epsilon   0.67, batch size   357, episode return 48.0
# Episode  19, epsilon   0.65, batch size   370, episode return 13.0
# Episode  20, epsilon   0.63, batch size   391, episode return 21.0
# Episode  21, epsilon   0.61, batch size   414, episode return 23.0
# Episode  22, epsilon   0.58, batch size   445, episode return 31.0
# Episode  23, epsilon   0.54, batch size   488, episode return 43.0
# Episode  24, epsilon   0.52, batch size   505, episode return 17.0
# Episode  25, epsilon   0.48, batch size   548, episode return 43.0
# Episode  26, epsilon   0.28, batch size   744, episode return 196.0
# Episode  27, epsilon   0.01, batch size  1111, episode return 367.0
# Episode  28, epsilon   0.01, batch size  1389, episode return 278.0
# Episode  29, epsilon   0.01, batch size  1633, episode return 244.0
# Episode  30, epsilon   0.01, batch size  1921, episode return 288.0
# Episode  31, epsilon   0.01, batch size  2197, episode return 276.0
# Episode  32, epsilon   0.01, batch size  2502, episode return 305.0
# Episode  33, epsilon   0.01, batch size  3111, episode return 609.0
# Episode  34, epsilon   0.01, batch size  3231, episode return 120.0
# Episode  35, epsilon   0.01, batch size  3314, episode return 83.0
# Episode  36, epsilon   0.01, batch size  3408, episode return 94.0
# Episode  37, epsilon   0.01, batch size  3506, episode return 98.0
# Episode  38, epsilon   0.01, batch size  3571, episode return 65.0
# Episode  39, epsilon   0.01, batch size  3634, episode return 63.0
# Episode  40, epsilon   0.01, batch size  3712, episode return 78.0
# Episode  41, epsilon   0.01, batch size  3818, episode return 106.0
# Episode  42, epsilon   0.01, batch size  3954, episode return 136.0
# Episode  43, epsilon   0.01, batch size  4062, episode return 108.0
# Episode  44, epsilon   0.01, batch size  4194, episode return 132.0
# Episode  45, epsilon   0.01, batch size  4426, episode return 232.0
# Episode  46, epsilon   0.01, batch size  4585, episode return 159.0
# Episode  47, epsilon   0.01, batch size  4854, episode return 269.0
# Episode  48, epsilon   0.01, batch size  4972, episode return 118.0
# Episode  49, epsilon   0.01, batch size  5111, episode return 139.0
# Episode  50, epsilon   0.01, batch size  5223, episode return 112.0
# Episode  51, epsilon   0.01, batch size  5399, episode return 176.0
# Episode  52, epsilon   0.01, batch size  5549, episode return 150.0
# Episode  53, epsilon   0.01, batch size  5690, episode return 141.0
# Episode  54, epsilon   0.01, batch size  5706, episode return 16.0
# Episode  55, epsilon   0.01, batch size  5856, episode return 150.0
# Episode  56, epsilon   0.01, batch size  5870, episode return 14.0
# Episode  57, epsilon   0.01, batch size  6021, episode return 151.0
# Episode  58, epsilon   0.01, batch size  6151, episode return 130.0
# Episode  59, epsilon   0.01, batch size  6402, episode return 251.0
# Episode  60, epsilon   0.01, batch size  6502, episode return 100.0
# Episode  61, epsilon   0.01, batch size  6727, episode return 225.0
# Episode  62, epsilon   0.01, batch size  6865, episode return 138.0
# Episode  63, epsilon   0.01, batch size  7173, episode return 308.0
# Episode  64, epsilon   0.01, batch size  7322, episode return 149.0
# Episode  65, epsilon   0.01, batch size  7469, episode return 147.0
# Episode  66, epsilon   0.01, batch size  7626, episode return 157.0
# Episode  67, epsilon   0.01, batch size  7777, episode return 151.0
# Episode  68, epsilon   0.01, batch size  8000, episode return 223.0
# Episode  69, epsilon   0.01, batch size  8195, episode return 195.0
# Episode  70, epsilon   0.01, batch size  8335, episode return 140.0
# Episode  71, epsilon   0.01, batch size  8476, episode return 141.0
# Episode  72, epsilon   0.01, batch size  8667, episode return 191.0
# Episode  73, epsilon   0.01, batch size  8810, episode return 143.0
# Episode  74, epsilon   0.01, batch size  8829, episode return 19.0
# Episode  75, epsilon   0.01, batch size  9018, episode return 189.0
# Episode  76, epsilon   0.01, batch size  9190, episode return 172.0
# Episode  77, epsilon   0.01, batch size  9375, episode return 185.0
# Episode  78, epsilon   0.01, batch size  9543, episode return 168.0
# Episode  79, epsilon   0.01, batch size  9663, episode return 120.0
# Episode  80, epsilon   0.01, batch size  9787, episode return 124.0
# Episode  81, epsilon   0.01, batch size  9802, episode return 15.0
# Episode  82, epsilon   0.01, batch size  9932, episode return 130.0
# Episode  83, epsilon   0.01, batch size 10115, episode return 183.0
# Episode  84, epsilon   0.01, batch size 10225, episode return 110.0
# Episode  85, epsilon   0.01, batch size 10334, episode return 109.0
# Episode  86, epsilon   0.01, batch size 10719, episode return 385.0
# Episode  87, epsilon   0.01, batch size 10826, episode return 107.0
# Episode  88, epsilon   0.01, batch size 10961, episode return 135.0
# Episode  89, epsilon   0.01, batch size 11157, episode return 196.0
# Episode  90, epsilon   0.01, batch size 11308, episode return 151.0
# Episode  91, epsilon   0.01, batch size 11476, episode return 168.0
# Episode  92, epsilon   0.01, batch size 11497, episode return 21.0
# Episode  93, epsilon   0.01, batch size 11661, episode return 164.0
# Episode  94, epsilon   0.01, batch size 11927, episode return 266.0
# Episode  95, epsilon   0.01, batch size 12079, episode return 152.0
# Episode  96, epsilon   0.01, batch size 12228, episode return 149.0
# Episode  97, epsilon   0.01, batch size 12375, episode return 147.0
# Episode  98, epsilon   0.01, batch size 12517, episode return 142.0
# Episode  99, epsilon   0.01, batch size 12635, episode return 118.0
# Episode 100, epsilon   0.01, batch size 12758, episode return 123.0

# %%
cartpole = gym.make("CartPole-v1", render_mode="human")

DQN.load_state_dict(torch.load("cart_pole_dqn.pth"))
s, _ = cartpole.reset()
for i in range(1000):
    a = greedy_action(DQN, s)
    s, _, d, _, _ = cartpole.step(a)
    if d:
        print(i)
        break

cartpole.close()
# Out:
# 115

# %% [markdown]
# # <div id="metrics"></div>Metrics
#
# Let's take a step back to reflect about what we really measure in the experiment above. We have counted the number of steps per training episode. But during these episodes, the applied policy was $\epsilon$-greedy, not greedy. So this is not an objective measure of performance.
#
# On the other hand, what is really being optimized here is the average sum of discounted rewards.
#
# <div class="alert alert-warning">
#
# **Exercise:**
# Enhance your previous code with the monitoring, after each episode, of:
# - the number of steps of the training episode
# - a Monte Carlo estimate of the total sum of rewards from the (distribution of) starting state,
# - a Monte Carlo estimate of the sum of discounted rewards from the (distribution of) starting state,
# - an average, over possible starting states $s_0$ of the current $\max_a Q(s_0,a)$.
# </div>

# %%
# %load solutions/RL5_exercise9.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

import numpy as np
import torch
from copy import deepcopy

class DQNAgent:
    def __init__(self, config, model):
        self.gamma = config["gamma"]
        self.batch_size = config["batch_size"]
        self.nb_actions = config["nb_actions"]
        self.memory = ReplayBuffer(config["buffer_size"])
        self.epsilon_max = config["epsilon_max"]
        self.epsilon_min = config["epsilon_min"]
        self.epsilon_stop = config["epsilon_decay_period"]
        self.epsilon_delay = config["epsilon_delay_decay"]
        self.epsilon_step = (self.epsilon_max - self.epsilon_min) / self.epsilon_stop
        self.nb_gradient_steps = config["gradient_steps"]
        self.nb_trials = config["nb_trials"]  # NEW NEW NEW
        self.total_steps = 0
        self.model = model
        self.criterion = torch.nn.SmoothL1Loss()
        self.optimizer = torch.optim.Adam(
            self.model.parameters(), lr=config["learning_rate"]
        )
        self.target_model = deepcopy(self.model).to(device)
        self.update_target_freq = config["update_target_freq"]

    def MC_eval(self, env, nb_trials):  # NEW NEW NEW
        MC_total_reward = []
        MC_discounted_reward = []
        for _ in range(nb_trials):
            s, _ = env.reset()
            done = False
            total_reward = 0
            discounted_reward = 0
            discount_factor = 1
            while not done:
                a = greedy_action(self.model, s)
                s, r, done, _, _ = env.step(a)
                total_reward += r
                discounted_reward += discount_factor * r
                discount_factor *= self.gamma
            MC_total_reward.append(total_reward)
            MC_discounted_reward.append(discounted_reward)
        return np.mean(MC_discounted_reward), np.mean(MC_total_reward)

    def eval_init_state(self, env, nb_trials):  # NEW NEW NEW
        with torch.no_grad():
            val = []
            for _ in range(nb_trials):
                s, _ = env.reset()
                val.append(
                    self.model(torch.Tensor(s).unsqueeze(0).to(device)).max().item()
                )
        return np.mean(val)

    def gradient_step(self):
        if len(self.memory) < self.batch_size:
            return

        # Sample from memory
        X, A, R, Y, D = self.memory.sample(self.batch_size)

        # Compute y_t = r(s, a) + \gamma * max_a' Q(s', a')
        QYmax = self.target_model(Y).max(1)[0].detach()
        update = torch.addcmul(R, 1 - D, QYmax, value=self.gamma)

        # Compute loss
        QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
        loss = self.criterion(QXA, update.unsqueeze(1))

        # Gradient step
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def train(self, env, max_episode):
        # Training monitoring
        episode_return = []
        MC_avg_total_reward = []  # NEW NEW NEW
        MC_avg_discounted_reward = []  # NEW NEW NEW
        avg_Q_init_state = []  # NEW NE W NEW

        # Initialization
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0

        while episode < max_episode:
            # Update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon - self.epsilon_step)

            # Select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = np.random.randint(self.nb_actions)
            else:
                action = greedy_action(self.model, state)

            # Step and store in memory
            next_state, reward, done, _, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward

            # Train
            for _ in range(self.nb_gradient_steps):
                self.gradient_step()

            # Update target network if needed
            if step % self.update_target_freq == 0:
                self.target_model.load_state_dict(self.model.state_dict())

            # Next transition
            step += 1
            if done:
                episode += 1

                # Monitoring
                if self.nb_trials > 0:  # NEW NEW NEW
                    MC_dr, MC_tr = self.MC_eval(env, self.nb_trials)
                    Q0 = self.eval_init_state(env, self.nb_trials)
                    MC_avg_total_reward.append(MC_tr)
                    MC_avg_discounted_reward.append(MC_dr)
                    avg_Q_init_state.append(Q0)
                    episode_return.append(episode_cum_reward)
                    print(
                        f"Episode {episode:2d}, epsilon {epsilon:6.2f},",
                        f"batch size {len(self.memory):4d}, ep return {episode_cum_reward:4.1f},",
                        f"MC tot {MC_tr:6.2f}, MC disc {MC_dr:6.2f}, Q0 {Q0:6.2f}",
                    )
                else:
                    episode_return.append(episode_cum_reward)
                    print(
                        f"Episode {episode:3d}, epsilon {epsilon:6.2f},",
                        f"batch size {len(self.memory):5d},",
                        f"episode return {episode_cum_reward:4.1f}",
                    )

                # Start new episode
                state, _ = env.reset()
                episode_cum_reward = 0
            else:
                state = next_state

        return (
            episode_return,
            MC_avg_discounted_reward,
            MC_avg_total_reward,
            avg_Q_init_state,
        )

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Use this monitoring to plot these values versus the number of episodes, after training.
# </div>

# %%
# %load solutions/RL5_exercise10.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

# Let's reset the Q function

import torch
import torch.nn as nn
import gymnasium as gym

cartpole = gym.make("CartPole-v1")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

state_dim = cartpole.observation_space.shape[0]
n_action = cartpole.action_space.n
nb_neurons = 24

# reset the Q function
DQN = torch.nn.Sequential(
    nn.Linear(state_dim, nb_neurons),
    nn.ReLU(),
    nn.Linear(nb_neurons, nb_neurons),
    nn.ReLU(),
    nn.Linear(nb_neurons, n_action),
).to(device)

config = {
    "observation_space": cartpole.observation_space.shape[0],
    "nb_actions": cartpole.action_space.n,
    "learning_rate": 0.001,
    "gamma": 0.95,
    "buffer_size": 1000000,
    "epsilon_min": 0.01,
    "epsilon_max": 1.0,
    "epsilon_decay_period": 1000,
    "epsilon_delay_decay": 20,
    "batch_size": 20,
    "gradient_steps": 10,
    "update_target_freq": 100,
    "nb_trials": 50,
}

agent = DQNAgent(config, DQN)
ep_length, disc_rewards, tot_rewards, Q0 = agent.train(cartpole, 100)

plt.plot(ep_length, label="Training episode length")
plt.plot(tot_rewards, label="MC eval of total reward")
plt.legend()
plt.figure()
plt.plot(disc_rewards, label="MC eval of discounted reward")
plt.plot(Q0, label="average $max_a Q(s_0)$")
plt.legend()
# Out:
# Episode  1, epsilon   1.00, batch size   24, ep return 24.0, MC tot  10.16, MC disc   8.11, Q0   0.39
# Episode  2, epsilon   0.96, batch size   59, ep return 35.0, MC tot   9.52, MC disc   7.72, Q0   1.00
# Episode  3, epsilon   0.95, batch size   76, ep return 17.0, MC tot   9.26, MC disc   7.55, Q0   0.98
# Episode  4, epsilon   0.93, batch size   94, ep return 18.0, MC tot   9.42, MC disc   7.66, Q0   1.01
# Episode  5, epsilon   0.91, batch size  113, ep return 19.0, MC tot   9.52, MC disc   7.72, Q0   1.92
# Episode  6, epsilon   0.87, batch size  156, ep return 43.0, MC tot  22.18, MC disc  13.46, Q0   1.95
# Episode  7, epsilon   0.85, batch size  176, ep return 20.0, MC tot  15.56, MC disc  10.74, Q0   2.02
# Episode  8, epsilon   0.83, batch size  196, ep return 20.0, MC tot  16.14, MC disc  11.21, Q0   2.02
# Episode  9, epsilon   0.81, batch size  217, ep return 21.0, MC tot  20.90, MC disc  13.04, Q0   2.86
# Episode 10, epsilon   0.78, batch size  244, ep return 27.0, MC tot  43.66, MC disc  17.24, Q0   2.85
# Episode 11, epsilon   0.77, batch size  254, ep return 10.0, MC tot  20.72, MC disc  12.99, Q0   2.93
# Episode 12, epsilon   0.75, batch size  273, ep return 19.0, MC tot  17.28, MC disc  11.69, Q0   2.92
# Episode 13, epsilon   0.74, batch size  284, ep return 11.0, MC tot  29.16, MC disc  15.42, Q0   2.86
# Episode 14, epsilon   0.71, batch size  309, ep return 25.0, MC tot  16.76, MC disc  11.47, Q0   3.82
# Episode 15, epsilon   0.69, batch size  339, ep return 30.0, MC tot  18.96, MC disc  12.36, Q0   3.83
# Episode 16, epsilon   0.67, batch size  352, ep return 13.0, MC tot  21.22, MC disc  13.14, Q0   3.80
# Episode 17, epsilon   0.66, batch size  369, ep return 17.0, MC tot  13.26, MC disc   9.83, Q0   3.85
# Episode 18, epsilon   0.64, batch size  387, ep return 18.0, MC tot  15.30, MC disc  10.79, Q0   3.80
# Episode 19, epsilon   0.62, batch size  402, ep return 15.0, MC tot   9.50, MC disc   7.71, Q0   4.77
# Episode 20, epsilon   0.57, batch size  458, ep return 56.0, MC tot  37.82, MC disc  16.20, Q0   4.64
# Episode 21, epsilon   0.54, batch size  483, ep return 25.0, MC tot  34.52, MC disc  15.88, Q0   4.56
# Episode 22, epsilon   0.52, batch size  501, ep return 18.0, MC tot  21.52, MC disc  13.16, Q0   4.55
# Episode 23, epsilon   0.50, batch size  531, ep return 30.0, MC tot  48.54, MC disc  17.71, Q0   5.27
# Episode 24, epsilon   0.41, batch size  614, ep return 83.0, MC tot 250.18, MC disc  20.00, Q0   6.26
# Episode 25, epsilon   0.36, batch size  663, ep return 49.0, MC tot 195.00, MC disc  20.00, Q0   6.23
# Episode 26, epsilon   0.22, batch size  812, ep return 149.0, MC tot 141.58, MC disc  19.98, Q0   7.66
# Episode 27, epsilon   0.12, batch size  906, ep return 94.0, MC tot 138.92, MC disc  19.97, Q0   8.36
# Episode 28, epsilon   0.03, batch size 1003, ep return 97.0, MC tot  89.20, MC disc  19.72, Q0   8.75
# Episode 29, epsilon   0.01, batch size 1080, ep return 77.0, MC tot  98.68, MC disc  19.84, Q0   8.99
# Episode 30, epsilon   0.01, batch size 1228, ep return 148.0, MC tot 111.80, MC disc  19.92, Q0  10.15
# Episode 31, epsilon   0.01, batch size 1364, ep return 136.0, MC tot 139.80, MC disc  19.98, Q0  10.62
# Episode 32, epsilon   0.01, batch size 1586, ep return 222.0, MC tot 247.92, MC disc  20.00, Q0  11.71
# Episode 33, epsilon   0.01, batch size 1966, ep return 380.0, MC tot 214.08, MC disc  20.00, Q0  13.43
# Episode 34, epsilon   0.01, batch size 2246, ep return 280.0, MC tot 212.00, MC disc  20.00, Q0  14.56
# Episode 35, epsilon   0.01, batch size 2486, ep return 240.0, MC tot 197.24, MC disc  20.00, Q0  15.25
# Episode 36, epsilon   0.01, batch size 2669, ep return 183.0, MC tot 161.30, MC disc  19.99, Q0  15.89
# Episode 37, epsilon   0.01, batch size 2821, ep return 152.0, MC tot 125.32, MC disc  19.97, Q0  16.53
# Episode 38, epsilon   0.01, batch size 2937, ep return 116.0, MC tot  96.04, MC disc  19.85, Q0  16.91
# Episode 39, epsilon   0.01, batch size 3023, ep return 86.0, MC tot  78.80, MC disc  19.64, Q0  17.13
# Episode 40, epsilon   0.01, batch size 3102, ep return 79.0, MC tot  65.64, MC disc  19.30, Q0  17.35
# Episode 41, epsilon   0.01, batch size 3159, ep return 57.0, MC tot  64.10, MC disc  19.23, Q0  17.34
# Episode 42, epsilon   0.01, batch size 3209, ep return 50.0, MC tot  52.92, MC disc  18.64, Q0  17.51
# Episode 43, epsilon   0.01, batch size 3264, ep return 55.0, MC tot  45.92, MC disc  18.03, Q0  17.59
# Episode 44, epsilon   0.01, batch size 3311, ep return 47.0, MC tot  46.72, MC disc  18.10, Q0  17.72
# Episode 45, epsilon   0.01, batch size 3358, ep return 47.0, MC tot  45.54, MC disc  18.01, Q0  17.65
# Episode 46, epsilon   0.01, batch size 3415, ep return 57.0, MC tot  45.22, MC disc  18.00, Q0  17.91
# Episode 47, epsilon   0.01, batch size 3458, ep return 43.0, MC tot  46.76, MC disc  18.14, Q0  17.91
# Episode 48, epsilon   0.01, batch size 3495, ep return 37.0, MC tot  47.48, MC disc  18.21, Q0  17.95
# Episode 49, epsilon   0.01, batch size 3543, ep return 48.0, MC tot  48.22, MC disc  18.27, Q0  18.24
# Episode 50, epsilon   0.01, batch size 3595, ep return 52.0, MC tot  47.54, MC disc  18.21, Q0  18.21
# Episode 51, epsilon   0.01, batch size 3664, ep return 69.0, MC tot  51.52, MC disc  18.54, Q0  18.43
# Episode 52, epsilon   0.01, batch size 3723, ep return 59.0, MC tot  53.14, MC disc  18.66, Q0  18.52
# Episode 53, epsilon   0.01, batch size 3778, ep return 55.0, MC tot 269.48, MC disc  20.00, Q0  18.40
# Episode 54, epsilon   0.01, batch size 3835, ep return 57.0, MC tot  47.38, MC disc  18.21, Q0  18.68
# Episode 55, epsilon   0.01, batch size 3889, ep return 54.0, MC tot  44.60, MC disc  17.92, Q0  18.63
# Episode 56, epsilon   0.01, batch size 3950, ep return 61.0, MC tot 126.88, MC disc  19.97, Q0  18.74
# Episode 57, epsilon   0.01, batch size 3999, ep return 49.0, MC tot  53.48, MC disc  18.69, Q0  18.75
# Episode 58, epsilon   0.01, batch size 4065, ep return 66.0, MC tot  44.42, MC disc  17.89, Q0  19.01
# Episode 59, epsilon   0.01, batch size 4132, ep return 67.0, MC tot  48.06, MC disc  18.25, Q0  18.99
# Episode 60, epsilon   0.01, batch size 4220, ep return 88.0, MC tot 210.22, MC disc  20.00, Q0  19.09
# Episode 61, epsilon   0.01, batch size 4277, ep return 57.0, MC tot 136.30, MC disc  19.98, Q0  19.10
# Episode 62, epsilon   0.01, batch size 4328, ep return 51.0, MC tot 149.38, MC disc  19.99, Q0  19.12
# Episode 63, epsilon   0.01, batch size 4383, ep return 55.0, MC tot  45.50, MC disc  18.01, Q0  19.15
# Episode 64, epsilon   0.01, batch size 4436, ep return 53.0, MC tot 116.30, MC disc  19.80, Q0  19.24
# Episode 65, epsilon   0.01, batch size 4515, ep return 79.0, MC tot  45.34, MC disc  18.00, Q0  19.18
# Episode 66, epsilon   0.01, batch size 4574, ep return 59.0, MC tot 136.74, MC disc  19.98, Q0  19.21
# Episode 67, epsilon   0.01, batch size 4627, ep return 53.0, MC tot 156.62, MC disc  19.99, Q0  19.29
# Episode 68, epsilon   0.01, batch size 4688, ep return 61.0, MC tot 129.78, MC disc  19.97, Q0  19.34
# Episode 69, epsilon   0.01, batch size 4787, ep return 99.0, MC tot 152.36, MC disc  19.96, Q0  19.40
# Episode 70, epsilon   0.01, batch size 4872, ep return 85.0, MC tot 128.32, MC disc  19.97, Q0  19.44
# Episode 71, epsilon   0.01, batch size 4990, ep return 118.0, MC tot  37.24, MC disc  16.93, Q0  19.49
# Episode 72, epsilon   0.01, batch size 5045, ep return 55.0, MC tot  32.06, MC disc  15.97, Q0  19.64
# Episode 73, epsilon   0.01, batch size 5087, ep return 42.0, MC tot 124.72, MC disc  19.97, Q0  19.62
# Episode 74, epsilon   0.01, batch size 5131, ep return 44.0, MC tot  30.78, MC disc  15.70, Q0  19.60
# Episode 75, epsilon   0.01, batch size 5173, ep return 42.0, MC tot  32.50, MC disc  16.09, Q0  19.61
# Episode 76, epsilon   0.01, batch size 5229, ep return 56.0, MC tot  32.64, MC disc  16.10, Q0  19.61
# Episode 77, epsilon   0.01, batch size 5275, ep return 46.0, MC tot  70.76, MC disc  16.91, Q0  19.55
# Episode 78, epsilon   0.01, batch size 5311, ep return 36.0, MC tot  34.14, MC disc  16.28, Q0  19.62
# Episode 79, epsilon   0.01, batch size 5348, ep return 37.0, MC tot  31.08, MC disc  15.74, Q0  19.69
# Episode 80, epsilon   0.01, batch size 5396, ep return 48.0, MC tot 136.98, MC disc  19.87, Q0  19.63
# Episode 81, epsilon   0.01, batch size 5442, ep return 46.0, MC tot  32.76, MC disc  16.11, Q0  19.74
# Episode 82, epsilon   0.01, batch size 5468, ep return 26.0, MC tot 138.78, MC disc  19.98, Q0  19.78
# Episode 83, epsilon   0.01, batch size 5497, ep return 29.0, MC tot 127.28, MC disc  19.97, Q0  19.81
# Episode 84, epsilon   0.01, batch size 5528, ep return 31.0, MC tot  31.82, MC disc  15.92, Q0  19.95
# Episode 85, epsilon   0.01, batch size 5562, ep return 34.0, MC tot  30.96, MC disc  15.78, Q0  19.89
# Episode 86, epsilon   0.01, batch size 5596, ep return 34.0, MC tot  92.28, MC disc  17.30, Q0  19.83
# Episode 87, epsilon   0.01, batch size 5624, ep return 28.0, MC tot 117.18, MC disc  19.95, Q0  20.00
# Episode 88, epsilon   0.01, batch size 5665, ep return 41.0, MC tot 120.66, MC disc  19.96, Q0  19.90
# Episode 89, epsilon   0.01, batch size 5698, ep return 33.0, MC tot  33.64, MC disc  16.25, Q0  19.88
# Episode 90, epsilon   0.01, batch size 5740, ep return 42.0, MC tot  38.70, MC disc  17.13, Q0  19.92
# Episode 91, epsilon   0.01, batch size 5780, ep return 40.0, MC tot  39.02, MC disc  17.17, Q0  20.00
# Episode 92, epsilon   0.01, batch size 5825, ep return 45.0, MC tot  37.30, MC disc  16.96, Q0  20.00
# Episode 93, epsilon   0.01, batch size 5874, ep return 49.0, MC tot  38.24, MC disc  17.08, Q0  20.06
# Episode 94, epsilon   0.01, batch size 5911, ep return 37.0, MC tot 116.28, MC disc  19.95, Q0  20.01
# Episode 95, epsilon   0.01, batch size 5953, ep return 42.0, MC tot 160.36, MC disc  19.97, Q0  20.05
# Episode 96, epsilon   0.01, batch size 5992, ep return 39.0, MC tot  38.48, MC disc  17.11, Q0  20.04
# Episode 97, epsilon   0.01, batch size 6032, ep return 40.0, MC tot  40.20, MC disc  17.35, Q0  20.05
# Episode 98, epsilon   0.01, batch size 6058, ep return 26.0, MC tot 116.06, MC disc  19.95, Q0  20.14
# Episode 99, epsilon   0.01, batch size 6111, ep return 53.0, MC tot  42.74, MC disc  17.69, Q0  20.03
# Episode 100, epsilon   0.01, batch size 6161, ep return 50.0, MC tot  42.12, MC disc  17.61, Q0  20.10

# %% [markdown]
# Remarks on CartPole:
# - Have you noted that Q overestimates the true value of the optimal policy? More on this in [this paper](https://papers.nips.cc/paper/3964-double-q-learning) if you are interested.
# - Have you noted that the greedy policy is optimal much sooner than the $Q$ function?
# - Have you remarked that the greedy policy performs well much sooner than the agent's policy (which is $\epsilon$-greedy)?
# - Can you anticipate the importance of well tuned exploration, for instance if the state space is much larger, or if parts of it are very hard to reach?
# - Can you anticipate the effect of taking a larger $\gamma$?

# %% [markdown]
# <span style="color:#3566B9">
#
# Pas tout compris, mais comme on fait une estimation avec un max, on tend à viser à chaque fois trop haut.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Train on SwingUp.
# </div>

# %%
# %load solutions/RL5_exercise11.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

# %%
DQN.load_state_dict(torch.load("swingup_dqn.pth"))

swingup = CartPoleSwingUp(render_mode="human")
s, _ = swingup.reset()
tot_rew = 0
for _ in range(1000):
    a = greedy_action(DQN, s)
    s, r, d, _, _ = swingup.step(a)
    tot_rew += r
    if d:
        break

print(f"Total nb steps: {i}, total reward: {tot_rew}")

swingup.close()

# %% [markdown]
# Remarks on SwingUp:
# - Did your DQN learn to avoid the -10 penalty instead of swinging up? The exploration question becomes a crucial issue, doesn't it?

# %% [markdown]
# # <div id="dqn-image"></div>DQN on image-based tasks
#
# Now it's time to turn towards Pong. As you noted earlier, the frame information in Pong is not sufficient to define an MDP, but stacking several frames together allows to recover the Markov property.
#
# We could wish to modify the previous replay buffer so that frames are stored only once (for memory efficiency). Then this new replay buffer would still need to return stacks of 4 frames when `sample()` is called.
#
# Fortunately, there's a simpler way to do that.
# We can use a wrapper (provided by Gym in this case) so that calling env.step(a) returns a stack of 4 frames.
# This wrapper actually only stores each frame once which optimizes memory efficiency. This way, we can keep on using our previous replay buffer class.

# %%
from gymnasium.wrappers import FrameStackObservation
pong = FrameStackObservation(pong, 4)

# %%
s, _ = pong.reset()
print(torch.Tensor(s).shape)

# %% [markdown]
# The two DQN papers ([Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602) and [Human-level control through deep reinforcement learning](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning)) actually introduce two different neural network architectures.
#
# The 2013 paper uses this architecture:
# - input: $84\times 84\times 4$ image (the last 4 frames)
# - layer 1: Convolutions with 16 filters of size $8\times 8$ and stride 4. The activation is a ReLU function.
# - layer 2: Convolutions with 32 filters of size $4\times 4$ and stride 2. The activation is a ReLU function.
# - layer 3: Fully connected with 256 ReLU units
# - layer 4 (output): Fully connected with 2 linear units (one for each action's value)
#
# The 2015 paper
# - input: $84\times 84\times 4$ image (the last 4 frames)
# - layer 1: Convolutions with 32 filters of size $8\times 8$ and stride 4. The activation is a ReLU function.
# - layer 2: Convolutions with 64 filters of size $4\times 4$ and stride 2. The activation is a ReLU function.
# - layer 3: Convolutions with 64 filters of size $3\times 3$ and stride 1. The activation is a ReLU function.
# - layer 4: Fully connected with 512 ReLU units
# - layer 5 (output): Fully connected with 2 linear units (one for each action's value)
#
# Also, it is a good practice to pre-fill the replay buffer with randomly sampled experience. The 2015 paper runs a random policy for 50000 steps to feed the replay buffer before training.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:** Create the corresponding neural network and adapt your optimization code from the previous exercice to train on Pong (you can take $C$ much larger, in the order of $10000$).
# </div>
#
# Caveat: unless you have a good GPU and a fair amount of time ahead of you (several hours or more), it is recommended to run this computation for a limited number of episodes, on a cloud computing service (or on a dediated machine).

# %%
# %load solutions/RL5_exercise12.py
### WRITE YOUR CODE HERE
# If you get stuck, uncomment the line above to load a correction in this cell (then you can execute this code).

# %% [markdown]
# To give you an idea of the behavior of a trained agent, you can check the following videos.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("p88R2_3yWPA")

# %%
YouTubeVideo("TmPfTpjtdgg")

# %% [markdown]
# # <div id="further"></div>Going further
#
# A lot of contributions have built on the initial success of DQN. Among those, some are combined and discussed in the **[Rainbow: Combining Improvements in Deep Reinforcement Learning](https://arxiv.org/abs/1710.02298)** paper. We will simply summarize their key ideas here, by decreasing order of importance (according to the paper).
#
# - N-step returns. Use samples that accumulate several returns rather than the 1-step return of TD(0).
# - [Prioritized experience replay](https://arxiv.org/abs/1511.05952). Inspired by the model-based [Prioritized Sweeping](https://link.springer.com/article/10.1007/BF00993104) approach, bias the distribution used to sample mini-batches in order to present high residual samples to the optimizer. Prioritized Sweeping is designed to accelerate the convergence in $L_\infty$ norm for tabular representations.
# - [Distributional value functions](https://arxiv.org/abs/1707.06887). Instead of estimating $\mathbb{E}(\sum_t \gamma^t r_t)$, estimate the distribution of $\sum_t \gamma^r r_t$ and iterate on it.
# - [NoisyNet](https://arxiv.org/abs/1706.10295). Instead of an $\epsilon$-greedy exploration strategy, introduce noise in the network's parameters to drive the exploration.
# - [Dueling architecture](https://arxiv.org/abs/1511.06581). The neural network's architecture splits $Q$ into the estimation of a value $V(s)$ and an advantage $A(s,a)$ with shared first layers.
# - [Double Q-learning](https://arxiv.org/abs/1509.06461). Q-learning is prone to over-estimation of the true optimal Q function (especially in high variance environments). Double Q-learning aims at compensating this weakness by introducing an under-estimation mechanism based on a second Q function.
#
# Beyond these improvements, new work is published each year that leads to a better understanding of the interplay between Deep Learning and RL.

# %% [markdown]
# # <div id="challenge"></div>Challenge
#
# In this challenge, we provide two new environments, on top of the SwingUp problem introduced before. All environments feature different difficulties. It is recommended that you focus on a single environment.

# %% [markdown]
# ## <div id="bicycle"></div>Bicycle
#
# This environment was originally introduced in the 1998 article on **[Learning to Drive a Bicycle Using Reinforcement Learning and Shaping](#https://www.researchgate.net/publication/221346431_Learning_to_Drive_a_Bicycle_Using_Reinforcement_Learning_and_Shaping)** by J. Randløv and P. Alstrøm. Notably, it was also one of the key benchmarks for **[Least Squares Policy Iteration](http://www.jmlr.org/papers/volume4/lagoudakis03a/lagoudakis03a.pdf)** by Lagoudakis and Parr in 2003.
#
# The environment provided here uses the exact same simulator but defines more rigorously the state variables. It is not a gym environment and has no `render` method, but it still provides the `step` and `reset` methods.
#
# In short, in this environment you try to ride a bicyle from an initial location $(x,y)=(0,0)$ to a goal that is located one kilometer further $(x_{goal},y_{goal})=(1000,0)$.
#
# The bicycle state variables are:
# - $\theta$ the angle of the handlebar
# - $\dot{\theta}$
# - $\omega$ the tilt angle between the $z$-axis and the bicycle+cyclist center of mass
# - $\dot{\omega}$
# - $x_b,y_b$ the position of the bicyle's back tire
# - $x_f,y_f$ the position of the bicyle's front tire
# - $\psi'_{goal}$ a not-so-useful variable kept for historical reasons, that is roughly proprotional to $\psi_{goal}$
# - $d_{goal}$ the distance between the front tire and the goal
# - $\psi$ the bicycle's heading angle (angle between the bicycle and the y-axis)
# - $\psi_{goal}$ the angle between the bicycle back wheel - front wheel axis, and the back wheel - goal axis
#
# The agent starts at $(x_b,y_b)=(0,0)$ with a random heading in $[-\pi,\pi]$, and random small values for $\theta$, $\dot{\theta}$, $\omega$ and $\dot{\omega}$ around the unstable equilibrium point.

# %%
from environments.bicycle import Bicycle
bike = Bicycle()
s, _ = bike.reset()
print(s)

# %% [markdown]
# The cyclist moves at a constant speed and his actions to control the bicycle consist in applying a torque to the handlebar or shifting his weight left or right. The action space is discrete and consists of 5 actions. What you pass to the `step` method is the action index.
#
# The episode ends when the tilt angle exceeds $\frac{\pi}{15}$.
#
# To encourage the bike staying up and guiding it towards the goal, the reward model uses *reward shaping*. It is written:
# $$r(s,a,s') = \omega^2 - \omega'^2 + k\cdot\left( d_{goal} - d'_{goal} \right)$$

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

print(bike.action_set)
S = []
s, _ = bike.reset()
S.append(s)
for i in range(1000):
    s, r, d, _, _ = bike.step(0)
    S.append(s)
    if d:
        break

print("trajectory length", len(S))
S = np.array(S)
plt.plot(S[:, 4], S[:, 5]);

# %% [markdown]
# ## <div id="sti"></div>Structured Treatment Interruptions
#
# This environment implements the simulator defined in **[Dynamic Multidrug Therapies for HIV: Optimal and STI Control Approaches](https://www.aimspress.com/fileOther/PDF/MBE/1551-0018_2004_2_223.pdf)** by B. M. Adams et al. (2004). It was notably used in **[Clinical data based optimal STI strategies for HIV: a reinforcement learning approach](https://ieeexplore.ieee.org/document/4177178)** by D. Ernst et al. (2006).
#
# This environment simulates the immune system of an HIV-infected patient. It is not a gym environment and has no `render` method, but it still provides the `step` and `reset` methods.
#
# In short, HIV can infect two types of cells (type 1 and type 2 below) and replicate itself, which increases the virus load in the blood stream. The immune system fights off the virus by increasing the concentration of macrophages (effector cells below).
#
# The patient state variables are:
# - $T_1$ healthy type 1 cells concentration (cells per mL)
# - $T_1^*$ infected type 1 cells concentration (cells per mL)
# - $T_2$ healthy type 2 cells concentration (cells per mL)
# - $T_2^*$ infected type 2 cells concentration (cells per mL)
# - $V$ free virus (copies per mL)
# - $E$ immune effector cells concentration (cells per mL)
#
# Once infected, if no treatment is applied, the patient naturally evolve to one of two steady states: either the immune system controls the infection and the patient is healthy, or the infection dominates and the patient is unhealthy.
#
# By default `reset` deterministically puts the patient in the infected unhealthy state.
#
#     The transition() function allows to simulate continuous time dynamics and control.
#     The step() function is tailored for the evaluation of Structured Treatment Interruptions.

# %%
from environments.hiv_patient import HIVPatient
patient = HIVPatient()
print("Uninfected patient:", patient.reset("uninfected")[0])
print("Unhealthy patient:", patient.reset()[0]) # actually equivalent to patient.reset("unhealthy")
print("Healthy patient:", patient.reset(mode="healthy")[0])

# %% [markdown]
# The `step` method simulates the evolution of the patient over a time step of $5$ days. The system is deterministic. For example, if we want to simulate a patient with a 25% immunity loss, with no treatment, over 400 days, we could do:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from environments.hiv_patient import HIVPatient

patient = HIVPatient()
s, _ = patient.reset(mode="healthy")
s[5] *= .75
patient.E *= .75
print(patient.E)
dur = 80 # 400/5
#nb_steps = int(dur//1e-3)
states = [s]
for _ in range(dur):
    s, r, d, _, _ = patient.step(0)
    states.append(s)
    
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E");

# %% [markdown]
# Two types of drugs can be given to the patient, that differ in the way they affect the viral load. The problem we look at consists in giving or not a certain drug at every step, to allow for **structured treatment interruptions** (STI). Such interruptions have double goal: train the immune system to react by itself and provide the patient with a better quality of life.
#
# The action space is discrete and consists of 5 actions. What you pass to the `step` method is the action index.
#
# The patient's death over the course of treatment is not explicitly modelled (but the viral load can reach very high values). So this simulator does not have a termination condition (`step` never returns `done=True`). The reward model discourages giving drugs, aims at a low viral load and a high immunity:
# $$r(s,a,s') = -k_V \cdot V + k_E \cdot E -k_1 R_2 - k_2 \cdot R_2$$
# where $R_1$ and $R_2$ are the amounts of prescribed drugs 1 and 2 respectively.

# %%
print(patient.action_set)

# %% [markdown]
# ## <div id="turn"></div>Your turn to play

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise (open-ended):**
# Your turn to play!
# Can you solve SwingUp? Bicycle? STI?
# Why are these problems more difficult than CartPole?
# Be creative!
# </div>
